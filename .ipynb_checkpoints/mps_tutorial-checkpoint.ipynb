# %% [markdown]
# ## Defining Hamiltonians in MPSKit

# %%
using MPSKit, MPSKitModels, TensorKit
using ProgressMeter, Plots

# %% [markdown]
# ## Spin operators
# In MPSKit, the operators are defined as TensorMaps. The typical examples are spin operators, but there are other operators such as fermionic operators. Further information can be found [here](https://github.com/maartenvd/MPSKitModels.jl/tree/master/test).

# %%
# We specify the spins in the “spin” argument.
spin = 1//2
println(S_x(spin=spin))
println(S_y(spin=spin))
println(S_z(spin=spin))
println(S_plus(spin=spin))
println(S_min(spin=spin))
# Out:
# TensorMap(ℂ^2 ← ℂ^2):
#  0.0 + 0.0im  0.5 + 0.0im
#  0.5 + 0.0im  0.0 + 0.0im
#
# TensorMap(ℂ^2 ← ℂ^2):
#  0.0 + 0.0im  0.0 - 0.5im
#  0.0 + 0.5im  0.0 + 0.0im
#
# TensorMap(ℂ^2 ← ℂ^2):
#  0.5 + 0.0im   0.0 + 0.0im
#  0.0 + 0.0im  -0.5 + 0.0im
#
# TensorMap(ℂ^2 ← ℂ^2):
#  0.0 + 0.0im  1.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# TensorMap(ℂ^2 ← ℂ^2):
#  0.0 + 0.0im  0.0 + 0.0im
#  1.0 + 0.0im  0.0 + 0.0im

# %% [markdown]
# Two site operator are also defined in the same way.

# %%
spin = 1//2
println(S_xx(spin=spin))
println(S_yy(spin=spin))
println(S_zz(spin=spin))
println(S_plusmin(spin=spin))
println(S_minplus(spin=spin))
# Out:
# TensorMap((ℂ^2 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^2)):
# [:, :, 1, 1] =
#  0.0 + 0.0im   0.0 + 0.0im
#  0.0 + 0.0im  0.25 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.25 + 0.0im
#  0.0 + 0.0im   0.0 + 0.0im
#
# [:, :, 1, 2] =
#   0.0 + 0.0im  0.0 + 0.0im
#  0.25 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 2] =
#  0.25 + 0.0im  0.0 + 0.0im
#   0.0 + 0.0im  0.0 + 0.0im
#
# TensorMap((ℂ^2 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^2)):
# [:, :, 1, 1] =
#  0.0 + 0.0im    0.0 + 0.0im
#  0.0 + 0.0im  -0.25 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.25 + 0.0im
#  0.0 + 0.0im   0.0 + 0.0im
#
# [:, :, 1, 2] =
#   0.0 + 0.0im  0.0 + 0.0im
#  0.25 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 2] =
#  -0.25 - 0.0im  0.0 + 0.0im
#    0.0 + 0.0im  0.0 + 0.0im
#
# TensorMap((ℂ^2 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^2)):
# [:, :, 1, 1] =
#  0.25 + 0.0im  0.0 + 0.0im
#   0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#    0.0 + 0.0im   0.0 + 0.0im
#  -0.25 + 0.0im  -0.0 + 0.0im
#
# [:, :, 1, 2] =
#  0.0 + 0.0im  -0.25 + 0.0im
#  0.0 + 0.0im   -0.0 + 0.0im
#
# [:, :, 2, 2] =
#   0.0 + 0.0im  -0.0 + 0.0im
#  -0.0 + 0.0im  0.25 - 0.0im
#
# TensorMap((ℂ^2 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^2)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 1, 2] =
#  0.0 + 0.0im  0.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 2] =
#  0.0 + 0.0im  0.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# TensorMap((ℂ^2 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^2)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 1, 2] =
#  0.0 + 0.0im  0.0 + 0.0im
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 2] =
#  0.0 + 0.0im  0.0 + 0.0im
#  0.0 + 0.0im  0.0 + 0.0im

# %% [markdown]
# Equivalently, we can define the two site operators using tensor product.

# %%
Z = S_z(spin = spin)
ZZ = Z ⊗ Z
ZZZ = Z ⊗ Z ⊗ Z

# \approx check if the two TensorMaps are close.
println(S_zz(spin=spin) ≈ ZZ)
# Out:
# true

# %% [markdown]
# In Julia, LaTeX format is supported. For example, $\sigma$ can be typed using “\sigma” and the tab key.
#
# The above tensor product $\otimes$ corresponds to “\otimes”.
#
# Lower and upper cases are a little tricky: You type “\sigma” + tab + “\\^z” + tab to obtain $\sigma^z$.

# %%
# Equivalent to 4*S_zz, yet written in the LaTeX format.
σᶻᶻ(spin=spin) ≈ 4*S_zz(spin=spin)
# Out:
# true

# %% [markdown]
# Ridiculous example might be the following. You might want to try some.

# %%
HₑₗₗₒWₒᵣₗᵈ = "Hello World"
print(HₑₗₗₒWₒᵣₗᵈ)
# Out:
# Hello World

# %% [markdown]
# # Constructing Hamiltonian(FiniteChain)
#
# Using spin operators, we can define Hamiltonian. Here, let us consider the transverse-field Ising model as an example!

# %%
# Definition of local terms. 
# Heisenberg term is XXZ_term = S_xx(spin=spin)+S_yy(spin=spin)+Δ*S_zz(spin=spin)
J = 1.0 
g = 1.0
ZZ_term = -J*4*S_zz(spin=spin)
X_term = -J*g*2*S_x(spin=spin)
# Out:
# TensorMap(ℂ^2 ← ℂ^2):
#  -0.0 - 0.0im  -1.0 - 0.0im
#  -1.0 - 0.0im  -0.0 - 0.0im

# %% [markdown]
# To construct the Hamiltonian,

# %%
L = 100
χ = 20
lattice = FiniteChain(L)
H_TF = @mpoham sum(nearest_neighbours(lattice)) do (i, j)
            return ZZ_term{i,j}
        end + sum(vertices(lattice)) do i
            # println(i)
            return X_term{i}
    end;

# %% [markdown]
# ### For more general purposes, we can rewrite as following

# %%
L = 100
χ = 20
lattice = FiniteChain(L)
H_TF = @mpoham sum(1:(L-1)) do i
            return ZZ_term{lattice[i],lattice[i+1]}
        end + sum(1:L) do i
            return X_term{lattice[i]}
        end 
# Add + sum(1:(L-2)) do i return ZZZ{lattice[i],lattice[i+1],lattice[i+2] end 
# if you like to add terms with more sites.
# Out:
# MPOHamiltonian{ComplexSpace, TrivialTensorMap{ComplexSpace, 2, 2, Matrix{ComplexF64}}, ComplexF64}(MPSKit.SparseMPOSlice{ComplexSpace, TrivialTensorMap{ComplexSpace, 2, 2, Matrix{ComplexF64}}, ComplexF64}[[TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ]  …  [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -1.4142135623730945 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.414213562373095 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ], [TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  -0.0 + 0.0im  -1.0 + 0.0im
#
# [:, :, 2, 1] =
#  -1.0 + 0.0im  0.0 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.7071067811865476 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  -0.7071067811865475 + 0.0im
# ; TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  0.0 + 0.0im
#  TensorMap((ℂ^1 ⊗ ℂ^2) ← (ℂ^2 ⊗ ℂ^1)):
# [:, :, 1, 1] =
#  1.0 + 0.0im  0.0 + 0.0im
#
# [:, :, 2, 1] =
#  0.0 + 0.0im  1.0 + 0.0im
# ]])

# %%
# 20 is bond dimension and C^2 is a physical space of spin-1/2
# If use C^(2*S+1) for spin-S systems.
state = FiniteMPS(rand,ComplexF64,L,ℂ^2,ℂ^χ)
# Out:
# 100-site FiniteMPS:
# ┌ CL[101]: TensorMap(ℂ^1 ← ℂ^1)
# ├── AL[100]: TensorMap((ℂ^2 ⊗ ℂ^2) ← ℂ^1)
# ├── AL[99]: TensorMap((ℂ^4 ⊗ ℂ^2) ← ℂ^2)
# ├── AL[98]: TensorMap((ℂ^8 ⊗ ℂ^2) ← ℂ^4)
# ├── AL[97]: TensorMap((ℂ^16 ⊗ ℂ^2) ← ℂ^8)
# ├── AL[96]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^16)
# ├── AL[95]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[94]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[93]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[92]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[91]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[90]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# │⋮
# ├── AL[10]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[9]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[8]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[7]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[6]: TensorMap((ℂ^20 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[5]: TensorMap((ℂ^16 ⊗ ℂ^2) ← ℂ^20)
# ├── AL[4]: TensorMap((ℂ^8 ⊗ ℂ^2) ← ℂ^16)
# ├── AL[3]: TensorMap((ℂ^4 ⊗ ℂ^2) ← ℂ^8)
# ├── AL[2]: TensorMap((ℂ^2 ⊗ ℂ^2) ← ℂ^4)
# └── AL[1]: TensorMap((ℂ^1 ⊗ ℂ^2) ← ℂ^2)

# %%
ψ₀, cache, delta = find_groundstate(state, H_TF, DMRG());
# Out:
# ┌ Info: DMRG iteration:
# │   iter = 1
# │   ϵ = 0.00013884653934121772
# │   λ = -126.96187566729944 - 5.636649063691828e-14im
# └   Δt = 6.512293263
# ┌ Info: DMRG iteration:
# │   iter = 2
# │   ϵ = 7.479865860785871e-7
# │   λ = -126.96187671143645 + 1.9188885002612155e-14im
# └   Δt = 5.309521021
# ┌ Info: DMRG iteration:
# │   iter = 3
# │   ϵ = 2.717646541240054e-7
# │   λ = -126.96187671750725 + 6.0615775027834096e-15im
# └   Δt = 3.646593603
# ┌ Info: DMRG iteration:
# │   iter = 4
# │   ϵ = 2.9049803841477773e-7
# │   λ = -126.96187672116459 + 1.1219968114040676e-14im
# └   Δt = 3.012879566
# ┌ Info: DMRG iteration:
# │   iter = 5
# │   ϵ = 2.83412610277337e-7
# │   λ = -126.96187672206008 - 5.701751043976765e-14im
# └   Δt = 2.290873737
# ┌ Info: DMRG iteration:
# │   iter = 6
# │   ϵ = 7.607871860289187e-8
# │   λ = -126.96187672210343 + 3.152752127611442e-14im
# └   Δt = 1.508374519
# ┌ Info: DMRG iteration:
# │   iter = 7
# │   ϵ = 1.3103835346905473e-8
# │   λ = -126.96187672210476 + 3.497965675331313e-14im
# └   Δt = 0.906518342
# ┌ Info: DMRG iteration:
# │   iter = 8
# │   ϵ = 2.280227555374136e-9
# │   λ = -126.96187672210488 + 1.905954304077737e-14im
# └   Δt = 0.585238686
# ┌ Info: DMRG iteration:
# │   iter = 9
# │   ϵ = 4.155985781971039e-10
# │   λ = -126.96187672210505 - 6.124141821276621e-14im
# └   Δt = 0.42964353
# ┌ Info: DMRG iteration:
# │   iter = 10
# │   ϵ = 3.3842685531058485e-10
# │   λ = -126.96187672210493 - 6.2128899398268536e-15im
# └   Δt = 0.327043481
# ┌ Info: DMRG iteration:
# │   iter = 11
# │   ϵ = 2.6689162867229216e-10
# │   λ = -126.96187672210498 - 1.97166943721354e-14im
# └   Δt = 0.261407514
# ┌ Info: DMRG iteration:
# │   iter = 12
# │   ϵ = 2.0625629907418e-10
# │   λ = -126.96187672210476 + 2.456185759871629e-14im
# └   Δt = 0.213130464
# ┌ Info: DMRG iteration:
# │   iter = 13
# │   ϵ = 1.574306268927726e-10
# │   λ = -126.96187672210506 - 4.351943874144437e-14im
# └   Δt = 0.180296193
# ┌ Info: DMRG iteration:
# │   iter = 14
# │   ϵ = 1.1927404369040269e-10
# │   λ = -126.96187672210476 - 4.127639113302029e-14im
# └   Δt = 0.154828937
# ┌ Info: DMRG iteration:
# │   iter = 15
# │   ϵ = 8.997126450941474e-11
# │   λ = -126.96187672210459 - 2.1333469103070467e-14im
# └   Δt = 0.138972041
# ┌ Info: DMRG iteration:
# │   iter = 16
# │   ϵ = 6.769508516003392e-11
# │   λ = -126.9618767221051 - 5.2885106274921654e-14im
# └   Δt = 0.132682547
# ┌ Info: DMRG iteration:
# │   iter = 17
# │   ϵ = 5.085983895753384e-11
# │   λ = -126.9618767221051 - 7.444574915535881e-14im
# └   Δt = 0.131769571
# ┌ Info: DMRG iteration:
# │   iter = 18
# │   ϵ = 3.817974935077738e-11
# │   λ = -126.9618767221049 - 2.0425017883249295e-14im
# └   Δt = 0.130311227
# ┌ Info: DMRG iteration:
# │   iter = 19
# │   ϵ = 2.864792413997184e-11
# │   λ = -126.96187672210482 - 3.8434620585419365e-14im
# └   Δt = 0.128892537
# ┌ Info: DMRG iteration:
# │   iter = 20
# │   ϵ = 2.149062366554866e-11
# │   λ = -126.96187672210482 + 6.500197595326586e-15im
# └   Δt = 0.127759268
# ┌ Info: DMRG iteration:
# │   iter = 21
# │   ϵ = 1.6119704972831042e-11
# │   λ = -126.96187672210503 - 1.7950438103348252e-14im
# └   Δt = 0.12811548
# ┌ Info: DMRG iteration:
# │   iter = 22
# │   ϵ = 1.2089697058054447e-11
# │   λ = -126.96187672210476 - 2.391177311796223e-14im
# └   Δt = 0.122303264
# ┌ Info: DMRG iteration:
# │   iter = 23
# │   ϵ = 9.06813502060587e-12
# │   λ = -126.96187672210482 + 5.91513623482375e-14im
# └   Δt = 0.122080052
# ┌ Info: DMRG iteration:
# │   iter = 24
# │   ϵ = 6.801950532707666e-12
# │   λ = -126.96187672210455 + 3.809427810381653e-14im
# └   Δt = 0.125026777
# ┌ Info: DMRG iteration:
# │   iter = 25
# │   ϵ = 5.102349485588211e-12
# │   λ = -126.96187672210513 - 1.4777964349838694e-14im
# └   Δt = 0.120879617
# ┌ Info: DMRG iteration:
# │   iter = 26
# │   ϵ = 3.827607601659098e-12
# │   λ = -126.96187672210463 + 4.0288147792852204e-14im
# └   Δt = 0.120407787
# ┌ Info: DMRG iteration:
# │   iter = 27
# │   ϵ = 2.8704948259950136e-12
# │   λ = -126.96187672210509 + 6.532944305367825e-15im
# └   Δt = 0.124608098
# ┌ Info: DMRG iteration:
# │   iter = 28
# │   ϵ = 2.1538123164265494e-12
# │   λ = -126.96187672210507 + 5.880895894477206e-14im
# └   Δt = 0.120170251
# ┌ Info: DMRG iteration:
# │   iter = 29
# │   ϵ = 1.6161611715501218e-12
# │   λ = -126.96187672210455 - 1.2735230719624969e-14im
# └   Δt = 0.123728862
# ┌ Info: DMRG iteration:
# │   iter = 30
# │   ϵ = 1.2127890051776845e-12
# │   λ = -126.9618767221052 + 2.7211967582094284e-15im
# └   Δt = 0.119198486
# ┌ Info: DMRG iteration:
# │   iter = 31
# │   ϵ = 9.095729260995456e-13
# │   λ = -126.96187672210459 - 1.0820326576483452e-13im
# └   Δt = 0.119090396
# ┌ Info: DMRG summary:
# │   ϵ = 2.0e-12
# │   λ = -126.96187672210459 - 1.0820326576483452e-13im
# └   Δt = 28.799909975

# %%
E₀ = sum(real(expectation_value(ψ₀,H_TF)))/(L)
# Out:
# -1.269618767221046

# %%
-4/pi
# Out:
# -1.2732395447351628

# %% [markdown]
# # Constructing Hamiltonian(InfiniteChain)

# %%
lattice∞ = InfiniteChain(1)
H_TF∞ = @mpoham sum(nearest_neighbours(lattice∞)) do (i, j)
            return ZZ_term{i,j}
        end + sum(vertices(lattice∞)) do i
            return X_term{i}
    end;

# %% [markdown]
# #### Equivalently, we can rewrite this as followings:

# %%
H_TF∞ = @mpoham sum(1:1) do i
            return ZZ_term{lattice∞[i],lattice∞[i+1]}
         end + sum(1:1) do i
            return X_term{lattice∞[i]}
    end;

# %%
random_data = TensorMap(rand, ComplexF64, ℂ^χ * ℂ^2, ℂ^χ);
state∞ = InfiniteMPS([random_data]);

# %%
# VUMPS can be seen as an upgrade of iDMRG
ψ₀, cache, delta = find_groundstate(state∞, H_TF∞, VUMPS());
# Out:
# ┌ Info: VUMPS iteration:
# │   iter = 1
# │   ϵ = 0.011606392350457493
# │   λ = -1.272275011416768 + 6.705790436822845e-17im
# └   Δt = 0.09755731
# ┌ Info: VUMPS iteration:
# │   iter = 2
# │   ϵ = 0.002413568646785689
# │   λ = -1.2731584520111094 - 2.959871930885427e-17im
# └   Δt = 0.043467514
# ┌ Info: VUMPS iteration:
# │   iter = 3
# │   ϵ = 0.0005711860657667198
# │   λ = -1.2732311068243538 + 1.919037845299343e-17im
# └   Δt = 0.024494756
# ┌ Info: VUMPS iteration:
# │   iter = 4
# │   ϵ = 0.00024808676140137013
# │   λ = -1.2732358867216709 + 5.854691731421724e-18im
# └   Δt = 0.03513276
# ┌ Info: VUMPS iteration:
# │   iter = 5
# │   ϵ = 0.00018061517379492517
# │   λ = -1.273237319764642 + 6.678685382510707e-17im
# └   Δt = 0.03630004
# ┌ Info: VUMPS iteration:
# │   iter = 6
# │   ϵ = 0.000137764560081493
# │   λ = -1.2732381782389597 + 3.642919299551295e-17im
# └   Δt = 0.02659047
# ┌ Info: VUMPS iteration:
# │   iter = 7
# │   ϵ = 0.00010484920181056617
# │   λ = -1.2732386762765502 - 6.657001339060997e-17im
# └   Δt = 0.036430525
# ┌ Info: VUMPS iteration:
# │   iter = 8
# │   ϵ = 7.94116092051131e-5
# │   λ = -1.2732389702264264 - 6.505213034913027e-19im
# └   Δt = 0.038105989
# ┌ Info: VUMPS iteration:
# │   iter = 9
# │   ϵ = 6.20968304581968e-5
# │   λ = -1.2732391502575018 + 8.890457814381136e-17im
# └   Δt = 0.041105356
# ┌ Info: VUMPS iteration:
# │   iter = 10
# │   ϵ = 4.9598731798805075e-5
# │   λ = -1.2732392639482835 + 4.5536491244391186e-17im
# └   Δt = 0.043072541
# ┌ Info: VUMPS iteration:
# │   iter = 11
# │   ϵ = 4.124795759176198e-5
# │   λ = -1.2732393367237087 + 8.153200337090993e-17im
# └   Δt = 0.046152605
# ┌ Info: VUMPS iteration:
# │   iter = 12
# │   ϵ = 3.604261668838329e-5
# │   λ = -1.2732393834976756 - 1.9949319973733282e-17im
# └   Δt = 0.053632962
# ┌ Info: VUMPS iteration:
# │   iter = 13
# │   ϵ = 3.200796345941947e-5
# │   λ = -1.2732394137707608 + 6.678685382510707e-17im
# └   Δt = 0.049677593
# ┌ Info: VUMPS iteration:
# │   iter = 14
# │   ϵ = 2.9241108541323776e-5
# │   λ = -1.2732394334836716 + 3.642919299551295e-17im
# └   Δt = 0.056144498
# ┌ Info: VUMPS iteration:
# │   iter = 15
# │   ϵ = 2.611504315387677e-5
# │   λ = -1.2732394464898744 + 3.469446951953614e-17im
# └   Δt = 0.054874759
# ┌ Info: VUMPS iteration:
# │   iter = 16
# │   ϵ = 2.3704383013175912e-5
# │   λ = -1.2732394551300372 - 4.5102810375396984e-17im
# └   Δt = 0.05927641
# ┌ Info: VUMPS iteration:
# │   iter = 17
# │   ϵ = 2.077280432578759e-5
# │   λ = -1.273239460937535 + 5.4643789493269423e-17im
# └   Δt = 0.054607245
# ┌ Info: VUMPS iteration:
# │   iter = 18
# │   ϵ = 1.8467846157150526e-5
# │   λ = -1.273239464856136 - 7.979727989493313e-17im
# └   Δt = 0.063079788
# ┌ Info: VUMPS iteration:
# │   iter = 19
# │   ϵ = 1.5879440423794187e-5
# │   λ = -1.2732394675183212 - 3.469446951953614e-18im
# └   Δt = 0.059086992
# ┌ Info: VUMPS iteration:
# │   iter = 20
# │   ϵ = 1.3815924220633334e-5
# │   λ = -1.2732394693320992 + 1.196959198423997e-16im
# └   Δt = 0.059387995
# ┌ Info: VUMPS iteration:
# │   iter = 21
# │   ϵ = 1.1716150781954123e-5
# │   λ = -1.2732394705697268 - 2.5153490401663703e-17im
# └   Δt = 0.06463762
# ┌ Info: VUMPS iteration:
# │   iter = 22
# │   ϵ = 1.0013220943701315e-5
# │   λ = -1.2732394714172586 - 1.708702623837155e-16im
# └   Δt = 0.059888081
# ┌ Info: VUMPS iteration:
# │   iter = 23
# │   ϵ = 8.419388589444167e-6
# │   λ = -1.2732394719959603 + 2.5153490401663703e-17im
# └   Δt = 0.065088238
# ┌ Info: VUMPS iteration:
# │   iter = 24
# │   ϵ = 7.1080455186659065e-6
# │   λ = -1.2732394723929057 + 9.71445146547012e-17im
# └   Δt = 0.060474774
# ┌ Info: VUMPS iteration:
# │   iter = 25
# │   ϵ = 5.950741450896695e-6
# │   λ = -1.2732394726636795 + 1.0842021724855044e-16im
# └   Δt = 0.067386683
# ┌ Info: VUMPS iteration:
# │   iter = 26
# │   ϵ = 4.9880178261178185e-6
# │   λ = -1.2732394728493288 - 3.2959746043559335e-17im
# └   Δt = 0.06217972
# ┌ Info: VUMPS iteration:
# │   iter = 27
# │   ϵ = 4.168102510087488e-6
# │   λ = -1.2732394729758045 - 4.683753385137379e-17im
# └   Δt = 0.065720771
# ┌ Info: VUMPS iteration:
# │   iter = 28
# │   ϵ = 3.4807470934109046e-6
# │   λ = -1.2732394730624197 + 2.949029909160572e-17im
# └   Δt = 0.061680868
# ┌ Info: VUMPS iteration:
# │   iter = 29
# │   ϵ = 2.9065196651436315e-6
# │   λ = -1.2732394731213748 + 3.642919299551295e-17im
# └   Δt = 0.067452609
# ┌ Info: VUMPS iteration:
# │   iter = 30
# │   ϵ = 2.4229454448312275e-6
# │   λ = -1.2732394731617056 + 1.1882855810441129e-16im
# └   Δt = 0.061561042
# ┌ Info: VUMPS iteration:
# │   iter = 31
# │   ϵ = 2.0227561794032884e-6
# │   λ = -1.2732394731891463 - 1.3183898417423734e-16im
# └   Δt = 0.063858311
# ┌ Info: VUMPS iteration:
# │   iter = 32
# │   ϵ = 1.6851052102988949e-6
# │   λ = -1.2732394732079038 + 6.505213034913027e-17im
# └   Δt = 0.05993838
# ┌ Info: VUMPS iteration:
# │   iter = 33
# │   ϵ = 1.406784276094573e-6
# │   λ = -1.273239473220667 - 9.454242944073599e-17im
# └   Δt = 0.064499947
# ┌ Info: VUMPS iteration:
# │   iter = 34
# │   ϵ = 1.1719176962126213e-6
# │   λ = -1.2732394732293906 - 1.708702623837155e-16im
# └   Δt = 0.060401767
# ┌ Info: VUMPS iteration:
# │   iter = 35
# │   ϵ = 9.78528690446661e-7
# │   λ = -1.2732394732353263 + 7.45931094670027e-17im
# └   Δt = 0.067410668
# ┌ Info: VUMPS iteration:
# │   iter = 36
# │   ϵ = 8.15458878267267e-7
# │   λ = -1.2732394732393875 - 6.071532165918825e-18im
# └   Δt = 0.060974473
# ┌ Info: VUMPS iteration:
# │   iter = 37
# │   ϵ = 6.811257174545649e-7
# │   λ = -1.2732394732421484 - 8.847089727481716e-17im
# └   Δt = 0.065695304
# ┌ Info: VUMPS iteration:
# │   iter = 38
# │   ϵ = 5.679790826133918e-7
# │   λ = -1.273239473244039 + 2.6020852139652106e-17im
# └   Δt = 0.061719197
# ┌ Info: VUMPS iteration:
# │   iter = 39
# │   ϵ = 4.7465822868143506e-7
# │   λ = -1.2732394732453276 - 7.806255641895632e-17im
# └   Δt = 0.065264456
# ┌ Info: VUMPS iteration:
# │   iter = 40
# │   ϵ = 3.961419170406177e-7
# │   λ = -1.2732394732462098 - 1.734723475976807e-18im
# └   Δt = 0.059806749
# ┌ Info: VUMPS iteration:
# │   iter = 41
# │   ϵ = 3.312779003235658e-7
# │   λ = -1.2732394732468122 + 7.892991815694472e-17im
# └   Δt = 0.06551537
# ┌ Info: VUMPS iteration:
# │   iter = 42
# │   ϵ = 2.767558874611932e-7
# │   λ = -1.2732394732472256 - 1.3877787807814457e-17im
# └   Δt = 0.060142087
# ┌ Info: VUMPS iteration:
# │   iter = 43
# │   ϵ = 2.316316435034877e-7
# │   λ = -1.2732394732475056 + 8.066464163292153e-17im
# └   Δt = 0.065946467
# ┌ Info: VUMPS iteration:
# │   iter = 44
# │   ϵ = 1.9372801484543764e-7
# │   λ = -1.2732394732476997 - 1.5872719805187785e-16im
# └   Δt = 0.060125295
# ┌ Info: VUMPS iteration:
# │   iter = 45
# │   ϵ = 1.6229763283864338e-7
# │   λ = -1.273239473247834 + 4.0766001685454967e-17im
# └   Δt = 0.065134036
# ┌ Info: VUMPS iteration:
# │   iter = 46
# │   ϵ = 1.359068643955254e-7
# │   λ = -1.2732394732479224 + 8.326672684688674e-17im
# └   Δt = 0.062406216
# ┌ Info: VUMPS iteration:
# │   iter = 47
# │   ϵ = 1.1398106463919286e-7
# │   λ = -1.2732394732479846 + 2.7755575615628914e-17im
# └   Δt = 0.064416336
# ┌ Info: VUMPS iteration:
# │   iter = 48
# │   ϵ = 9.557239469469046e-8
# │   λ = -1.2732394732480299 - 4.423544863740858e-17im
# └   Δt = 0.061022294
# ┌ Info: VUMPS iteration:
# │   iter = 49
# │   ϵ = 8.024851271278439e-8
# │   λ = -1.2732394732480579 - 2.3592239273284576e-16im
# └   Δt = 0.064907704
# ┌ Info: VUMPS iteration:
# │   iter = 50
# │   ϵ = 6.738050920917691e-8
# │   λ = -1.2732394732480794 + 6.071532165918825e-17im
# └   Δt = 0.061419715
# ┌ Info: VUMPS iteration:
# │   iter = 51
# │   ϵ = 5.664831692870023e-8
# │   λ = -1.273239473248092 - 2.6020852139652106e-17im
# └   Δt = 0.067165943
# ┌ Info: VUMPS iteration:
# │   iter = 52
# │   ϵ = 4.763233956292445e-8
# │   λ = -1.2732394732481027 + 4.85722573273506e-17im
# └   Δt = 0.063098904
# ┌ Info: VUMPS iteration:
# │   iter = 53
# │   ϵ = 4.009864875275277e-8
# │   λ = -1.2732394732481105 - 1.5178830414797062e-16im
# └   Δt = 0.066437473
# ┌ Info: VUMPS iteration:
# │   iter = 54
# │   ϵ = 3.376571767364214e-8
# │   λ = -1.2732394732481123 - 2.7755575615628914e-17im
# └   Δt = 0.062873604
# ┌ Info: VUMPS iteration:
# │   iter = 55
# │   ϵ = 2.8464089828310566e-8
# │   λ = -1.2732394732481174 + 8.066464163292153e-17im
# └   Δt = 0.066933884
# ┌ Info: VUMPS iteration:
# │   iter = 56
# │   ϵ = 2.4003833522570886e-8
# │   λ = -1.2732394732481183 + 1.5612511283791264e-17im
# └   Δt = 0.061132018
# ┌ Info: VUMPS iteration:
# │   iter = 57
# │   ϵ = 2.0263121117350323e-8
# │   λ = -1.2732394732481187 - 1.2663481374630692e-16im
# └   Δt = 0.066225137
# ┌ Info: VUMPS iteration:
# │   iter = 58
# │   ϵ = 1.711302276528633e-8
# │   λ = -1.2732394732481225 - 1.1882855810441129e-16im
# └   Δt = 0.066756919
# ┌ Info: VUMPS iteration:
# │   iter = 59
# │   ϵ = 1.446641481091509e-8
# │   λ = -1.2732394732481214 + 9.80118763926896e-17im
# └   Δt = 0.060573639
# ┌ Info: VUMPS iteration:
# │   iter = 60
# │   ϵ = 1.2235266694347378e-8
# │   λ = -1.2732394732481216 + 9.540979117872439e-18im
# └   Δt = 0.06575336
# ┌ Info: VUMPS iteration:
# │   iter = 61
# │   ϵ = 1.0357445932068404e-8
# │   λ = -1.2732394732481234 - 1.0061396160665481e-16im
# └   Δt = 0.060872695
# ┌ Info: VUMPS iteration:
# │   iter = 62
# │   ϵ = 8.772565185672901e-9
# │   λ = -1.2732394732481218 - 1.214306433183765e-17im
# └   Δt = 0.064723113
# ┌ Info: VUMPS iteration:
# │   iter = 63
# │   ϵ = 7.436408103919385e-9
# │   λ = -1.2732394732481218 + 1.3877787807814457e-17im
# └   Δt = 0.060596531
# ┌ Info: VUMPS iteration:
# │   iter = 64
# │   ϵ = 6.30729884206902e-9
# │   λ = -1.2732394732481245 + 1.9081958235744878e-17im
# └   Δt = 0.066228241
# ┌ Info: VUMPS iteration:
# │   iter = 65
# │   ϵ = 5.353819437488504e-9
# │   λ = -1.2732394732481223 - 4.9439619065339e-17im
# └   Δt = 0.058419221
# ┌ Info: VUMPS iteration:
# │   iter = 66
# │   ϵ = 4.547078602765766e-9
# │   λ = -1.2732394732481245 - 8.326672684688674e-17im
# └   Δt = 0.063827942
# ┌ Info: VUMPS iteration:
# │   iter = 67
# │   ϵ = 3.86474183361238e-9
# │   λ = -1.2732394732481243 - 5.984795992119984e-17im
# └   Δt = 0.057877658
# ┌ Info: VUMPS iteration:
# │   iter = 68
# │   ϵ = 3.286675918908805e-9
# │   λ = -1.2732394732481214 + 1.240327285323417e-16im
# └   Δt = 0.063674783
# ┌ Info: VUMPS iteration:
# │   iter = 69
# │   ϵ = 2.79700935890829e-9
# │   λ = -1.273239473248125 + 2.862293735361732e-17im
# └   Δt = 0.059081135
# ┌ Info: VUMPS iteration:
# │   iter = 70
# │   ϵ = 2.381630138075556e-9
# │   λ = -1.2732394732481216 - 2.42861286636753e-17im
# └   Δt = 0.062133887
# ┌ Info: VUMPS iteration:
# │   iter = 71
# │   ϵ = 2.029258551256401e-9
# │   λ = -1.2732394732481231 - 9.71445146547012e-17im
# └   Δt = 0.057569055
# ┌ Info: VUMPS iteration:
# │   iter = 72
# │   ϵ = 1.7299719352948107e-9
# │   λ = -1.273239473248125 + 3.5561831257524545e-17im
# └   Δt = 0.067860473
# ┌ Info: VUMPS iteration:
# │   iter = 73
# │   ϵ = 1.4757242353322721e-9
# │   λ = -1.2732394732481245 - 7.806255641895632e-18im
# └   Δt = 0.058571721
# ┌ Info: VUMPS iteration:
# │   iter = 74
# │   ϵ = 1.259504877295102e-9
# │   λ = -1.2732394732481236 - 6.505213034913027e-17im
# └   Δt = 0.064713891
# ┌ Info: VUMPS iteration:
# │   iter = 75
# │   ϵ = 1.075583536509003e-9
# │   λ = -1.273239473248123 + 7.37257477290143e-17im
# └   Δt = 0.058389869
# ┌ Info: VUMPS iteration:
# │   iter = 76
# │   ϵ = 9.189899398816334e-10
# │   λ = -1.273239473248124 - 7.979727989493313e-17im
# └   Δt = 0.063813455
# ┌ Info: VUMPS iteration:
# │   iter = 77
# │   ϵ = 7.85621398226338e-10
# │   λ = -1.273239473248124 - 5.2909066017292616e-17im
# └   Δt = 0.058462398
# ┌ Info: VUMPS iteration:
# │   iter = 78
# │   ϵ = 6.719288756386905e-10
# │   λ = -1.273239473248124 - 9.71445146547012e-17im
# └   Δt = 0.062561507
# ┌ Info: VUMPS iteration:
# │   iter = 79
# │   ϵ = 5.74981745956048e-10
# │   λ = -1.2732394732481236 - 1.0061396160665481e-16im
# └   Δt = 0.057726478
# ┌ Info: VUMPS iteration:
# │   iter = 80
# │   ϵ = 4.922564536601831e-10
# │   λ = -1.2732394732481243 - 1.9081958235744878e-17im
# └   Δt = 0.063812404
# ┌ Info: VUMPS iteration:
# │   iter = 81
# │   ϵ = 4.2163396267805103e-10
# │   λ = -1.2732394732481247 - 5.898059818321144e-17im
# └   Δt = 0.054680601
# ┌ Info: VUMPS iteration:
# │   iter = 82
# │   ϵ = 3.6129947608540285e-10
# │   λ = -1.2732394732481243 + 3.5561831257524545e-17im
# └   Δt = 0.060372214
# ┌ Info: VUMPS iteration:
# │   iter = 83
# │   ϵ = 3.0973793552550506e-10
# │   λ = -1.2732394732481236 - 6.071532165918825e-18im
# └   Δt = 0.054486516
# ┌ Info: VUMPS iteration:
# │   iter = 84
# │   ϵ = 2.6564087640040333e-10
# │   λ = -1.273239473248125 + 4.683753385137379e-17im
# └   Δt = 0.058005937
# ┌ Info: VUMPS iteration:
# │   iter = 85
# │   ϵ = 2.2792236443708251e-10
# │   λ = -1.2732394732481247 - 6.678685382510707e-17im
# └   Δt = 0.055038897
# ┌ Info: VUMPS iteration:
# │   iter = 86
# │   ϵ = 1.9563805003693504e-10
# │   λ = -1.2732394732481243 + 7.025630077706069e-17im
# └   Δt = 0.053113204
# ┌ Info: VUMPS iteration:
# │   iter = 87
# │   ϵ = 1.6799465950519615e-10
# │   λ = -1.2732394732481231 + 2.5153490401663703e-17im
# └   Δt = 0.059471033
# ┌ Info: VUMPS iteration:
# │   iter = 88
# │   ϵ = 1.443109697320724e-10
# │   λ = -1.273239473248122 + 1.6046192152785466e-16im
# └   Δt = 0.051929561
# ┌ Info: VUMPS iteration:
# │   iter = 89
# │   ϵ = 1.2401434843229172e-10
# │   λ = -1.273239473248125 + 7.19910242530375e-17im
# └   Δt = 0.052501263
# ┌ Info: VUMPS iteration:
# │   iter = 90
# │   ϵ = 1.0660445365806213e-10
# │   λ = -1.273239473248125 + 1.8214596497756474e-17im
# └   Δt = 0.057849715
# ┌ Info: VUMPS iteration:
# │   iter = 91
# │   ϵ = 9.16720501242581e-11
# │   λ = -1.273239473248124 - 7.719519468096792e-17im
# └   Δt = 0.052373335
# ┌ Info: VUMPS iteration:
# │   iter = 92
# │   ϵ = 7.885905082741877e-11
# │   λ = -1.2732394732481238 + 2.168404344971009e-17im
# └   Δt = 0.052053607
# ┌ Info: VUMPS iteration:
# │   iter = 93
# │   ϵ = 6.78593769540468e-11
# │   λ = -1.2732394732481258 + 3.903127820947816e-17im
# └   Δt = 0.057426658
# ┌ Info: VUMPS iteration:
# │   iter = 94
# │   ϵ = 5.8412948891951e-11
# │   λ = -1.2732394732481243 + 1.2576745200831851e-16im
# └   Δt = 0.051517789
# ┌ Info: VUMPS iteration:
# │   iter = 95
# │   ϵ = 5.029774261278691e-11
# │   λ = -1.2732394732481231 - 1.8821749714348357e-16im
# └   Δt = 0.052493565
# ┌ Info: VUMPS iteration:
# │   iter = 96
# │   ϵ = 4.331974129225522e-11
# │   λ = -1.2732394732481227 + 8.326672684688674e-17im
# └   Δt = 0.056690313
# ┌ Info: VUMPS iteration:
# │   iter = 97
# │   ϵ = 3.7330045330848026e-11
# │   λ = -1.273239473248124 - 1.0321604682062002e-16im
# └   Δt = 0.051554611
# ┌ Info: VUMPS iteration:
# │   iter = 98
# │   ϵ = 3.216653253522652e-11
# │   λ = -1.2732394732481245 + 9.627715291671279e-17im
# └   Δt = 0.052002903
# ┌ Info: VUMPS iteration:
# │   iter = 99
# │   ϵ = 2.77337250721417e-11
# │   λ = -1.2732394732481236 - 1.3010426069826053e-17im
# └   Δt = 0.055439675
# ┌ Info: VUMPS iteration:
# │   iter = 100
# │   ϵ = 2.391693745959367e-11
# │   λ = -1.273239473248124 - 1.6566609195578508e-16im
# └   Δt = 0.04829718
# ┌ Warning: VUMPS maximum iterations
# │   iter = 100
# │   ϵ = 2.391693745959367e-11
# │   λ = -1.273239473248124 - 1.6566609195578508e-16im
# └ @ MPSKit ~/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:94
# ┌ Info: VUMPS summary:
# │   ϵ = 2.391693745959367e-11
# │   λ = -1.273239473248124 - 1.6566609195578508e-16im
# └   Δt = 6.623071883

# %%
E₀ = real(expectation_value(ψ₀,H_TF∞))[0]
println("Exact ground state energy : ",-4/pi)
println("Numerical results : ", E₀)
println("Numerical errors : ", E₀+4/pi)
# Out:
# Exact ground state energy : -1.2732395447351628
# Numerical results : -1.2732394732481251
# Numerical errors : 7.148703762283048e-8

# %%
transferplot(ψ₀, ψ₀)

# %%
entanglementplot(ψ₀)
