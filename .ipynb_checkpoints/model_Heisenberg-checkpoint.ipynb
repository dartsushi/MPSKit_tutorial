# %% [markdown]
# # The XXZ model
#
# In this file we will give step by step instructions on how to analyze the spin 1/2 XXZ model.
# The necessary packages to follow this tutorial are:

# %%
using MPSKit, MPSKitModels, TensorKit, Plots

# %%
\sigma

# %% [markdown]
# ## Failure
#
# First we should define the hamiltonian we want to work with.
# Then we specify an initial guess, which we then further optimize.
# Working directly in the thermodynamic limit, this is achieved as follows:

# %%
H = heisenberg_XXX(; spin=1);

# %% [markdown]
# We then need an intial state, which we shall later optimize. In this example we work directly in the thermodynamic limit.

# %%
random_data = TensorMap(rand, ComplexF64, ℂ^20 * ℂ^3, ℂ^20);
state = InfiniteMPS([random_data]);

# %% [markdown]
# The groundstate can then be found by calling `find_groundstate`.

# %%
groundstate, cache, delta = find_groundstate(state, H, VUMPS());
# Out:
# ┌ Info: VUMPS iteration:
# │   iter = 1
# │   ϵ = 0.4207727739280671
# │   λ = -0.006407227519025737 - 2.7755575615628914e-17im
# └   Δt = 0.069541307
# ┌ Info: VUMPS iteration:
# │   iter = 2
# │   ϵ = 0.2209635599055152
# │   λ = -1.2659472964804666 + 3.122502256758253e-17im
# └   Δt = 0.030547563
# ┌ Info: VUMPS iteration:
# │   iter = 3
# │   ϵ = 0.01787063001492202
# │   λ = -1.4004105860891563 - 1.5612511283791264e-17im
# └   Δt = 0.042925458
# ┌ Info: VUMPS iteration:
# │   iter = 4
# │   ϵ = 0.005759252049101256
# │   λ = -1.4014029804958432 + 1.43982048506075e-16im
# └   Δt = 0.034652373
# ┌ Info: VUMPS iteration:
# │   iter = 5
# │   ϵ = 0.005915588097900174
# │   λ = -1.4014224981425543 + 1.5612511283791264e-17im
# └   Δt = 0.021067811
# ┌ Info: VUMPS iteration:
# │   iter = 6
# │   ϵ = 0.005477730266158323
# │   λ = -1.4014290484159564 + 4.163336342344337e-17im
# └   Δt = 0.027298235
# ┌ Info: VUMPS iteration:
# │   iter = 7
# │   ϵ = 0.005627849311578735
# │   λ = -1.4014274529599775 + 5.204170427930421e-17im
# └   Δt = 0.018722544
# ┌ Info: VUMPS iteration:
# │   iter = 8
# │   ϵ = 0.0054201761502129745
# │   λ = -1.4014289813891485 - 8.326672684688674e-17im
# └   Δt = 0.025336771
# ┌ Info: VUMPS iteration:
# │   iter = 9
# │   ϵ = 0.0048818153010057
# │   λ = -1.401434856127618 + 6.418476861114186e-17im
# └   Δt = 0.020725906
# ┌ Info: VUMPS iteration:
# │   iter = 10
# │   ϵ = 0.006571079136462099
# │   λ = -1.4014127086806618 + 2.7755575615628914e-17im
# └   Δt = 0.02746738
# ┌ Info: VUMPS iteration:
# │   iter = 11
# │   ϵ = 0.005758127855202548
# │   λ = -1.401423780344501 - 8.673617379884035e-18im
# └   Δt = 0.020563502
# ┌ Info: VUMPS iteration:
# │   iter = 12
# │   ϵ = 0.00527307040406413
# │   λ = -1.401429120947958 + 2.0816681711721685e-17im
# └   Δt = 0.027065602
# ┌ Info: VUMPS iteration:
# │   iter = 13
# │   ϵ = 0.004921166930380723
# │   λ = -1.4014336148104287 - 7.632783294297951e-17im
# └   Δt = 0.020470188
# ┌ Info: VUMPS iteration:
# │   iter = 14
# │   ϵ = 0.00495292698661336
# │   λ = -1.401434459402383 + 4.683753385137379e-17im
# └   Δt = 0.027344151
# ┌ Info: VUMPS iteration:
# │   iter = 15
# │   ϵ = 0.0052627106034146024
# │   λ = -1.4014308489993872 + 1.3877787807814457e-17im
# └   Δt = 0.018678988
# ┌ Info: VUMPS iteration:
# │   iter = 16
# │   ϵ = 0.004843959797135502
# │   λ = -1.4014348967679489 + 1.3877787807814457e-17im
# └   Δt = 0.027104465
# ┌ Info: VUMPS iteration:
# │   iter = 17
# │   ϵ = 0.005664102087813221
# │   λ = -1.4014255577012658 - 1.0408340855860843e-17im
# └   Δt = 0.020658927
# ┌ Info: VUMPS iteration:
# │   iter = 18
# │   ϵ = 0.0052538038669981205
# │   λ = -1.401430558982979 + 5.204170427930421e-17im
# └   Δt = 0.027049131
# ┌ Info: VUMPS iteration:
# │   iter = 19
# │   ϵ = 0.00477229453107351
# │   λ = -1.4014360532343564 - 2.0816681711721685e-17im
# └   Δt = 0.020789354
# ┌ Info: VUMPS iteration:
# │   iter = 20
# │   ϵ = 0.005663578634799223
# │   λ = -1.401427020822777 - 2.0816681711721685e-17im
# └   Δt = 0.027423459
# ┌ Info: VUMPS iteration:
# │   iter = 21
# │   ϵ = 0.0047163896597345895
# │   λ = -1.4014365508811424 - 4.85722573273506e-17im
# └   Δt = 0.020567969
# ┌ Info: VUMPS iteration:
# │   iter = 22
# │   ϵ = 0.005940279449108797
# │   λ = -1.4014217180640949 + 4.85722573273506e-17im
# └   Δt = 0.027338948
# ┌ Info: VUMPS iteration:
# │   iter = 23
# │   ϵ = 0.005265905754229536
# │   λ = -1.4014301036872259 - 6.938893903907228e-18im
# └   Δt = 0.020891302
# ┌ Info: VUMPS iteration:
# │   iter = 24
# │   ϵ = 0.004358874872401967
# │   λ = -1.4014398308442313 - 3.2959746043559335e-17im
# └   Δt = 0.027271893
# ┌ Info: VUMPS iteration:
# │   iter = 25
# │   ϵ = 0.004818606045347741
# │   λ = -1.4014361384132255 - 4.336808689942018e-17im
# └   Δt = 0.018695598
# ┌ Info: VUMPS iteration:
# │   iter = 26
# │   ϵ = 0.00460545616220696
# │   λ = -1.4014382371401697 - 5.724587470723463e-17im
# └   Δt = 0.02720298
# ┌ Info: VUMPS iteration:
# │   iter = 27
# │   ϵ = 0.004563648266183222
# │   λ = -1.4014382276077557 + 5.898059818321144e-17im
# └   Δt = 0.018789102
# ┌ Info: VUMPS iteration:
# │   iter = 28
# │   ϵ = 0.004956014124065001
# │   λ = -1.4014334652849032 + 3.2959746043559335e-17im
# └   Δt = 0.027385246
# ┌ Info: VUMPS iteration:
# │   iter = 29
# │   ϵ = 0.0044265505549346
# │   λ = -1.4014392851826076 + 2.42861286636753e-17im
# └   Δt = 0.020796628
# ┌ Info: VUMPS iteration:
# │   iter = 30
# │   ϵ = 0.003975277909620829
# │   λ = -1.4014435474939846 - 8.500145032286355e-17im
# └   Δt = 0.027159421
# ┌ Info: VUMPS iteration:
# │   iter = 31
# │   ϵ = 0.004225159614784676
# │   λ = -1.4014411604869284 - 2.0816681711721685e-17im
# └   Δt = 0.020641692
# ┌ Info: VUMPS iteration:
# │   iter = 32
# │   ϵ = 0.004424767255894664
# │   λ = -1.4014390065958882 - 7.112366251504909e-17im
# └   Δt = 0.027213679
# ┌ Info: VUMPS iteration:
# │   iter = 33
# │   ϵ = 0.004287645390054737
# │   λ = -1.401440621348991 - 5.0306980803327406e-17im
# └   Δt = 0.018789125
# ┌ Info: VUMPS iteration:
# │   iter = 34
# │   ϵ = 0.0038132492623006685
# │   λ = -1.4014454932548221 - 2.2551405187698492e-17im
# └   Δt = 0.027234828
# ┌ Info: VUMPS iteration:
# │   iter = 35
# │   ϵ = 0.003915097540300784
# │   λ = -1.4014435864898442 - 4.5102810375396984e-17im
# └   Δt = 0.020755045
# ┌ Info: VUMPS iteration:
# │   iter = 36
# │   ϵ = 0.0038963358031151056
# │   λ = -1.4014443585262328 - 2.7755575615628914e-17im
# └   Δt = 0.025143952
# ┌ Info: VUMPS iteration:
# │   iter = 37
# │   ϵ = 0.0037354071640853456
# │   λ = -1.4014450786408996 - 4.85722573273506e-17im
# └   Δt = 0.020942354
# ┌ Info: VUMPS iteration:
# │   iter = 38
# │   ϵ = 0.003409200843343367
# │   λ = -1.4014481146375315 + 4.5102810375396984e-17im
# └   Δt = 0.027013725
# ┌ Info: VUMPS iteration:
# │   iter = 39
# │   ϵ = 0.003408719764272662
# │   λ = -1.4014485532652787 - 1.0408340855860843e-17im
# └   Δt = 0.025209919
# ┌ Info: VUMPS iteration:
# │   iter = 40
# │   ϵ = 0.00345408646031291
# │   λ = -1.4014474918652557 + 2.42861286636753e-17im
# └   Δt = 0.020630908
# ┌ Info: VUMPS iteration:
# │   iter = 41
# │   ϵ = 0.003547768860877679
# │   λ = -1.4014465246843855 - 1.5612511283791264e-17im
# └   Δt = 0.027174446
# ┌ Info: VUMPS iteration:
# │   iter = 42
# │   ϵ = 0.0033484578955922514
# │   λ = -1.4014487859410303 + 3.2959746043559335e-17im
# └   Δt = 0.018836824
# ┌ Info: VUMPS iteration:
# │   iter = 43
# │   ϵ = 0.002890989268967477
# │   λ = -1.4014515183054963 - 1.214306433183765e-17im
# └   Δt = 0.025362469
# ┌ Info: VUMPS iteration:
# │   iter = 44
# │   ϵ = 0.0029491372910667043
# │   λ = -1.401451364026291 - 1.0408340855860843e-17im
# └   Δt = 0.01881069
# ┌ Info: VUMPS iteration:
# │   iter = 45
# │   ϵ = 0.0030523290337576368
# │   λ = -1.401450289532102 + 3.469446951953614e-17im
# └   Δt = 0.025250847
# ┌ Info: VUMPS iteration:
# │   iter = 46
# │   ϵ = 0.003517011739893379
# │   λ = -1.4014457150024227 - 4.85722573273506e-17im
# └   Δt = 0.020962466
# ┌ Info: VUMPS iteration:
# │   iter = 47
# │   ϵ = 0.0028660402781331166
# │   λ = -1.4014514767471886 - 7.28583859910259e-17im
# └   Δt = 0.027209979
# ┌ Info: VUMPS iteration:
# │   iter = 48
# │   ϵ = 0.002573488825117155
# │   λ = -1.4014536840600471 - 5.204170427930421e-17im
# └   Δt = 0.018917626
# ┌ Info: VUMPS iteration:
# │   iter = 49
# │   ϵ = 0.002476185581556595
# │   λ = -1.4014536956663093 + 4.163336342344337e-17im
# └   Δt = 0.027119457
# ┌ Info: VUMPS iteration:
# │   iter = 50
# │   ϵ = 0.002584724259645287
# │   λ = -1.40145348697556 - 5.204170427930421e-18im
# └   Δt = 0.018761034
# ┌ Info: VUMPS iteration:
# │   iter = 51
# │   ϵ = 0.00289666271076744
# │   λ = -1.4014502134469269 - 3.122502256758253e-17im
# └   Δt = 0.027485503
# ┌ Info: VUMPS iteration:
# │   iter = 52
# │   ϵ = 0.0029504876689097305
# │   λ = -1.4014500371577636 + 2.2551405187698492e-17im
# └   Δt = 0.018879999
# ┌ Info: VUMPS iteration:
# │   iter = 53
# │   ϵ = 0.0023418775517025947
# │   λ = -1.4014545664280575 - 9.367506770274758e-17im
# └   Δt = 0.027203268
# ┌ Info: VUMPS iteration:
# │   iter = 54
# │   ϵ = 0.002372920141425903
# │   λ = -1.401454027752565 + 3.469446951953614e-17im
# └   Δt = 0.018733693
# ┌ Info: VUMPS iteration:
# │   iter = 55
# │   ϵ = 0.002420286053697278
# │   λ = -1.4014538767665763 - 4.336808689942018e-17im
# └   Δt = 0.025420097
# ┌ Info: VUMPS iteration:
# │   iter = 56
# │   ϵ = 0.0026105383944388955
# │   λ = -1.4014526987743678 + 3.469446951953614e-18im
# └   Δt = 0.021021177
# ┌ Info: VUMPS iteration:
# │   iter = 57
# │   ϵ = 0.0022935439611078776
# │   λ = -1.401454119544861 + 1.734723475976807e-18im
# └   Δt = 0.027342778
# ┌ Info: VUMPS iteration:
# │   iter = 58
# │   ϵ = 0.002126969652289273
# │   λ = -1.4014551694703368 - 2.7755575615628914e-17im
# └   Δt = 0.018829061
# ┌ Info: VUMPS iteration:
# │   iter = 59
# │   ϵ = 0.0021738798657111066
# │   λ = -1.4014550291621928 + 5.724587470723463e-17im
# └   Δt = 0.02726315
# ┌ Info: VUMPS iteration:
# │   iter = 60
# │   ϵ = 0.002172550580772563
# │   λ = -1.401454550896965 - 9.71445146547012e-17im
# └   Δt = 0.020693224
# ┌ Info: VUMPS iteration:
# │   iter = 61
# │   ϵ = 0.0021373245031021657
# │   λ = -1.4014549121477666 + 6.245004513516506e-17im
# └   Δt = 0.025709414
# ┌ Info: VUMPS iteration:
# │   iter = 62
# │   ϵ = 0.0019839538475935926
# │   λ = -1.4014558253693483 - 9.540979117872439e-17im
# └   Δt = 0.019073773
# ┌ Info: VUMPS iteration:
# │   iter = 63
# │   ϵ = 0.001879713004419618
# │   λ = -1.4014559086418117 - 3.122502256758253e-17im
# └   Δt = 0.025549981
# ┌ Info: VUMPS iteration:
# │   iter = 64
# │   ϵ = 0.001904727724797739
# │   λ = -1.4014559567651157 - 1.5612511283791264e-17im
# └   Δt = 0.018965564
# ┌ Info: VUMPS iteration:
# │   iter = 65
# │   ϵ = 0.0019288886555635899
# │   λ = -1.4014557539124401 - 4.5102810375396984e-17im
# └   Δt = 0.027330245
# ┌ Info: VUMPS iteration:
# │   iter = 66
# │   ϵ = 0.0018993135716610153
# │   λ = -1.4014555841455243 + 8.500145032286355e-17im
# └   Δt = 0.019045908
# ┌ Info: VUMPS iteration:
# │   iter = 67
# │   ϵ = 0.0017404729868729743
# │   λ = -1.4014565305136992 + 1.9081958235744878e-17im
# └   Δt = 0.025498421
# ┌ Info: VUMPS iteration:
# │   iter = 68
# │   ϵ = 0.0017225875228971772
# │   λ = -1.4014565916614026 + 2.7755575615628914e-17im
# └   Δt = 0.018989728
# ┌ Info: VUMPS iteration:
# │   iter = 69
# │   ϵ = 0.0016991302106910506
# │   λ = -1.4014563917978475 + 2.42861286636753e-17im
# └   Δt = 0.025535827
# ┌ Info: VUMPS iteration:
# │   iter = 70
# │   ϵ = 0.0016536742753719144
# │   λ = -1.401456756108797 + 2.7755575615628914e-17im
# └   Δt = 0.018834643
# ┌ Info: VUMPS iteration:
# │   iter = 71
# │   ϵ = 0.001634219150234679
# │   λ = -1.4014567718455142 + 2.949029909160572e-17im
# └   Δt = 0.027443697
# ┌ Info: VUMPS iteration:
# │   iter = 72
# │   ϵ = 0.0015920793692580945
# │   λ = -1.4014567079057572 + 5.724587470723463e-17im
# └   Δt = 0.019120678
# ┌ Info: VUMPS iteration:
# │   iter = 73
# │   ϵ = 0.0015233604145328476
# │   λ = -1.401457162231775 - 2.6020852139652106e-17im
# └   Δt = 0.025602523
# ┌ Info: VUMPS iteration:
# │   iter = 74
# │   ϵ = 0.001530566593620979
# │   λ = -1.4014570304565537 - 2.6020852139652106e-17im
# └   Δt = 0.018903487
# ┌ Info: VUMPS iteration:
# │   iter = 75
# │   ϵ = 0.0015002402980537383
# │   λ = -1.4014569711865326 + 3.8163916471489756e-17im
# └   Δt = 0.025505535
# ┌ Info: VUMPS iteration:
# │   iter = 76
# │   ϵ = 0.001436687187560803
# │   λ = -1.4014573137043165 + 1.3877787807814457e-16im
# └   Δt = 0.019060627
# ┌ Info: VUMPS iteration:
# │   iter = 77
# │   ϵ = 0.001418371466411805
# │   λ = -1.4014573177670735 - 6.938893903907228e-18im
# └   Δt = 0.027440964
# ┌ Info: VUMPS iteration:
# │   iter = 78
# │   ϵ = 0.001404591236752579
# │   λ = -1.4014572113931527 - 1.734723475976807e-17im
# └   Δt = 0.019044128
# ┌ Info: VUMPS iteration:
# │   iter = 79
# │   ϵ = 0.0013226059504921244
# │   λ = -1.4014576297061585 + 3.9898639947466563e-17im
# └   Δt = 0.027412214
# ┌ Info: VUMPS iteration:
# │   iter = 80
# │   ϵ = 0.001336535487679245
# │   λ = -1.401457478512755 - 1.9081958235744878e-17im
# └   Δt = 0.018984901
# ┌ Info: VUMPS iteration:
# │   iter = 81
# │   ϵ = 0.0012944102040142451
# │   λ = -1.4014575377790626 - 1.214306433183765e-17im
# └   Δt = 0.025636402
# ┌ Info: VUMPS iteration:
# │   iter = 82
# │   ϵ = 0.0012583205999986363
# │   λ = -1.4014576951971398 + 6.245004513516506e-17im
# └   Δt = 0.018994277
# ┌ Info: VUMPS iteration:
# │   iter = 83
# │   ϵ = 0.0012378737671473066
# │   λ = -1.4014576959926779 + 3.122502256758253e-17im
# └   Δt = 0.027377994
# ┌ Info: VUMPS iteration:
# │   iter = 84
# │   ϵ = 0.0012277927166657364
# │   λ = -1.4014576475790876 - 2.7755575615628914e-17im
# └   Δt = 0.019080508
# ┌ Info: VUMPS iteration:
# │   iter = 85
# │   ϵ = 0.0011268113911334532
# │   λ = -1.401458032903131 + 4.5102810375396984e-17im
# └   Δt = 0.027456569
# ┌ Info: VUMPS iteration:
# │   iter = 86
# │   ϵ = 0.0011370149311850143
# │   λ = -1.401457908582872 + 9.540979117872439e-17im
# └   Δt = 0.019181419
# ┌ Info: VUMPS iteration:
# │   iter = 87
# │   ϵ = 0.0010976898743007045
# │   λ = -1.4014580016195195 + 1.734723475976807e-17im
# └   Δt = 0.025560057
# ┌ Info: VUMPS iteration:
# │   iter = 88
# │   ϵ = 0.001032379443882312
# │   λ = -1.4014581877924428 + 1.1622647289044608e-16im
# └   Δt = 0.018967098
# ┌ Info: VUMPS iteration:
# │   iter = 89
# │   ϵ = 0.0010533300852588216
# │   λ = -1.401458066628332 - 3.122502256758253e-17im
# └   Δt = 0.02545829
# ┌ Info: VUMPS iteration:
# │   iter = 90
# │   ϵ = 0.0010180176635324121
# │   λ = -1.4014581376288213 + 4.336808689942018e-17im
# └   Δt = 0.018995875
# ┌ Info: VUMPS iteration:
# │   iter = 91
# │   ϵ = 0.0009687001044393325
# │   λ = -1.401458285257437 - 1.734723475976807e-18im
# └   Δt = 0.025641552
# ┌ Info: VUMPS iteration:
# │   iter = 92
# │   ϵ = 0.0009849548845420816
# │   λ = -1.401458175529082 - 5.724587470723463e-17im
# └   Δt = 0.019138362
# ┌ Info: VUMPS iteration:
# │   iter = 93
# │   ϵ = 0.0009400494360892726
# │   λ = -1.4014582877885708 + 7.45931094670027e-17im
# └   Δt = 0.025553042
# ┌ Info: VUMPS iteration:
# │   iter = 94
# │   ϵ = 0.000902161963223432
# │   λ = -1.4014583690423377 - 1.196959198423997e-16im
# └   Δt = 0.019115923
# ┌ Info: VUMPS iteration:
# │   iter = 95
# │   ϵ = 0.0009167104860212011
# │   λ = -1.4014582868726342 + 4.163336342344337e-17im
# └   Δt = 0.02564971
# ┌ Info: VUMPS iteration:
# │   iter = 96
# │   ϵ = 0.0008734331628776163
# │   λ = -1.4014583838616348 + 3.469446951953614e-18im
# └   Δt = 0.019216258
# ┌ Info: VUMPS iteration:
# │   iter = 97
# │   ϵ = 0.0008467658341117866
# │   λ = -1.4014584385860127 + 5.204170427930421e-18im
# └   Δt = 0.025592408
# ┌ Info: VUMPS iteration:
# │   iter = 98
# │   ϵ = 0.0008539276946251633
# │   λ = -1.4014583804420941 - 1.0408340855860843e-17im
# └   Δt = 0.019125602
# ┌ Info: VUMPS iteration:
# │   iter = 99
# │   ϵ = 0.0008134911361888926
# │   λ = -1.4014584709428963 - 3.642919299551295e-17im
# └   Δt = 0.025614744
# ┌ Info: VUMPS iteration:
# │   iter = 100
# │   ϵ = 0.0007915640902867604
# │   λ = -1.4014584992217494 - 5.204170427930421e-18im
# └   Δt = 0.01909831
# ┌ Warning: VUMPS maximum iterations
# │   iter = 100
# │   ϵ = 0.0007915640902867604
# │   λ = -1.4014584992217494 - 5.204170427930421e-18im
# └ @ MPSKit ~/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:94
# ┌ Info: VUMPS summary:
# │   ϵ = 0.0007915640902867604
# │   λ = -1.4014584992217494 - 5.204170427930421e-18im
# └   Δt = 2.428610863

# %% [markdown]
# As you can see, VUMPS struggles to converge.
# On it's own, that is already quite curious.
# Maybe we can do better using another algorithm, such as gradient descent.

# %%
groundstate, cache, delta = find_groundstate(state, H, GradientGrassmann(; maxiter=20));
# Out:
# [ Info: CG: initializing with f = 0.886792669205, ‖∇f‖ = 1.0245e+00
# [ Info: CG: iter    1: f = 0.125506878353, ‖∇f‖ = 1.6984e+00, α = 2.29e+01, β = 0.00e+00, nfg = 4
# [ Info: CG: iter    2: f = -0.007932709473, ‖∇f‖ = 1.5088e+00, α = 2.17e+03, β = 2.42e+02, nfg = 5
# [ Info: CG: iter    3: f = -0.029424320183, ‖∇f‖ = 1.3765e+00, α = 7.18e+02, β = 1.47e-02, nfg = 6
# [ Info: CG: iter    4: f = -0.283949142513, ‖∇f‖ = 1.4909e+00, α = 5.52e-01, β = 7.84e-01, nfg = 19
# [ Info: CG: iter    5: f = -0.310440787791, ‖∇f‖ = 1.5866e+00, α = 8.45e-01, β = 3.98e-01, nfg = 2
# [ Info: CG: iter    6: f = -0.466493616071, ‖∇f‖ = 1.6415e+00, α = 8.24e-01, β = 2.38e-01, nfg = 3
# [ Info: CG: iter    7: f = -0.555391486889, ‖∇f‖ = 1.6774e+00, α = 7.97e-01, β = 2.49e-01, nfg = 3
# [ Info: CG: iter    8: f = -0.563418090990, ‖∇f‖ = 1.8305e+00, α = 7.97e-01, β = 2.10e-01, nfg = 2
# [ Info: CG: iter    9: f = -0.836157402121, ‖∇f‖ = 1.6700e+00, α = 5.92e-01, β = 2.22e-01, nfg = 4
# [ Info: CG: iter   10: f = -1.077199932669, ‖∇f‖ = 1.4629e+00, α = 4.84e-01, β = 1.88e-01, nfg = 3
# [ Info: CG: iter   11: f = -1.273331038213, ‖∇f‖ = 9.1600e-01, α = 3.27e-01, β = 1.63e-01, nfg = 3
# [ Info: CG: iter   12: f = -1.323001644191, ‖∇f‖ = 6.4134e-01, α = 2.97e-01, β = 1.04e-01, nfg = 2
# [ Info: CG: iter   13: f = -1.350676709124, ‖∇f‖ = 4.3438e-01, α = 2.58e-01, β = 1.91e-01, nfg = 2
# [ Info: CG: iter   14: f = -1.367525295049, ‖∇f‖ = 3.1095e-01, α = 2.25e-01, β = 1.99e-01, nfg = 2
# [ Info: CG: iter   15: f = -1.376854379312, ‖∇f‖ = 2.7576e-01, α = 1.35e-01, β = 5.50e-01, nfg = 2
# [ Info: CG: iter   16: f = -1.381050669061, ‖∇f‖ = 2.8072e-01, α = 5.10e-02, β = 1.32e+00, nfg = 2
# [ Info: CG: iter   17: f = -1.387669108286, ‖∇f‖ = 2.9063e-01, α = 1.20e-01, β = 4.24e-01, nfg = 3
# [ Info: CG: iter   18: f = -1.393565473982, ‖∇f‖ = 2.3249e-01, α = 9.69e-02, β = 5.18e-01, nfg = 2
# [ Info: CG: iter   19: f = -1.397494236374, ‖∇f‖ = 1.7090e-01, α = 1.11e-01, β = 4.42e-01, nfg = 2
# ┌ Warning: CG: not converged to requested tol: f = -1.399502806199, ‖∇f‖ = 9.4083e-02
# └ @ OptimKit ~/.julia/packages/OptimKit/xpmbV/src/cg.jl:103

# %% [markdown]
# Convergence is quite slow and even fails after sufficiently many iterations.
# To understand why, we can look at the transfer matrix spectrum.

# %%
transferplot(groundstate, groundstate)

# %% [markdown]
# We can clearly see multiple eigenvalues close to the unit circle.
# Our state is close to being non-injective, and represents the sum of multiple injective states.
# This is numerically very problematic, but also indicates that we used an incorrect ansatz to approximate the groundstate.
# We should retry with a larger unit cell.

# %% [markdown]
# ## Success
#
# Let's initialize a different initial state, this time with a 2-site unit cell:

# %%
A = TensorMap(rand, ComplexF64, ℂ^20 * ℂ^3, ℂ^20);
B = TensorMap(rand, ComplexF64, ℂ^20 * ℂ^3, ℂ^20);
state = InfiniteMPS([A, B]);

# %% [markdown]
# In MPSKit, we require that the periodicity of the hamiltonian equals that of the state it is applied to.
# This is not a big obstacle, you can simply repeat the original hamiltonian.
# Alternatively, the hamiltonian can be constructed directly on a two-site unitcell by making use of MPSKitModels.jl's `@mpoham`.

# %%
# H2 = repeat(H, 2); -- copies the one-site version
H2 = heisenberg_XXX(ComplexF64, Trivial, InfiniteChain(2); spin=1)
groundstate, cache, delta = find_groundstate(
    state, H2, VUMPS(; maxiter=100, tol_galerkin=1e-12)
);
# Out:
# ┌ Info: VUMPS iteration:
# │   iter = 1
# │   ϵ = 0.4106507288617756
# │   λ = -1.678891878231502 + 3.122502256758253e-17im
# └   Δt = 0.067059347
# ┌ Info: VUMPS iteration:
# │   iter = 2
# │   ϵ = 0.0535867144831595
# │   λ = -2.752355083832045 - 3.2959746043559335e-17im
# └   Δt = 0.04429703
# ┌ Info: VUMPS iteration:
# │   iter = 3
# │   ϵ = 0.01889519925380709
# │   λ = -2.7914301414762313 + 1.102633609417758e-16im
# └   Δt = 0.044994335
# ┌ Info: VUMPS iteration:
# │   iter = 4
# │   ϵ = 0.009588453333734351
# │   λ = -2.8011283724590754 - 1.3877787807814457e-17im
# └   Δt = 0.044364874
# ┌ Info: VUMPS iteration:
# │   iter = 5
# │   ϵ = 0.0044664468032803075
# │   λ = -2.8027700590141187 + 1.1362438767648086e-16im
# └   Δt = 0.050525048
# ┌ Info: VUMPS iteration:
# │   iter = 6
# │   ϵ = 0.003933680899102066
# │   λ = -2.8028858674070865 + 6.765421556309548e-17im
# └   Δt = 0.044711585
# ┌ Info: VUMPS iteration:
# │   iter = 7
# │   ϵ = 0.0038144159767004335
# │   λ = -2.80289214055931 - 1.3357370765021415e-16im
# └   Δt = 0.044434791
# ┌ Info: VUMPS iteration:
# │   iter = 8
# │   ϵ = 0.0037010498252904923
# │   λ = -2.8028931290338788 - 1.2576745200831851e-17im
# └   Δt = 0.044405598
# ┌ Info: VUMPS iteration:
# │   iter = 9
# │   ϵ = 0.0038312042557551674
# │   λ = -2.8028928434841065 - 8.174884380540703e-17im
# └   Δt = 0.042047785
# ┌ Info: VUMPS iteration:
# │   iter = 10
# │   ϵ = 0.003929439615409376
# │   λ = -2.8028901506528197 + 1.098296800727816e-16im
# └   Δt = 0.041499764
# ┌ Info: VUMPS iteration:
# │   iter = 11
# │   ϵ = 0.004143530042038127
# │   λ = -2.802888974050192 - 1.973247953923618e-17im
# └   Δt = 0.041462207
# ┌ Info: VUMPS iteration:
# │   iter = 12
# │   ϵ = 0.00395944896667586
# │   λ = -2.8028873828162073 - 1.0061396160665481e-16im
# └   Δt = 0.041684274
# ┌ Info: VUMPS iteration:
# │   iter = 13
# │   ϵ = 0.0037554523435276953
# │   λ = -2.8028928371209894 + 1.6479873021779667e-17im
# └   Δt = 0.041405624
# ┌ Info: VUMPS iteration:
# │   iter = 14
# │   ϵ = 0.003724226995240384
# │   λ = -2.8028930304386996 - 9.84455572616838e-17im
# └   Δt = 0.041551691
# ┌ Info: VUMPS iteration:
# │   iter = 15
# │   ϵ = 0.003525431408276148
# │   λ = -2.802895176804662 - 8.565197162635485e-17im
# └   Δt = 0.041696534
# ┌ Info: VUMPS iteration:
# │   iter = 16
# │   ϵ = 0.003906904760853026
# │   λ = -2.8028904161205945 - 1.5699247457590104e-16im
# └   Δt = 0.041559435
# ┌ Info: VUMPS iteration:
# │   iter = 17
# │   ϵ = 0.0036911863815324
# │   λ = -2.802892315866659 + 7.589415207398531e-18im
# └   Δt = 0.041453029
# ┌ Info: VUMPS iteration:
# │   iter = 18
# │   ϵ = 0.003779858764520853
# │   λ = -2.8028949199940927 + 5.453536927602087e-17im
# └   Δt = 0.04175736
# ┌ Info: VUMPS iteration:
# │   iter = 19
# │   ϵ = 0.0032692209898554214
# │   λ = -2.8028982412566426 - 1.870248747537495e-17im
# └   Δt = 0.041443748
# ┌ Info: VUMPS iteration:
# │   iter = 20
# │   ϵ = 0.0033875420131327764
# │   λ = -2.8028964896972237 + 8.565197162635485e-17im
# └   Δt = 0.035200324
# ┌ Info: VUMPS iteration:
# │   iter = 21
# │   ϵ = 0.0034177896984130414
# │   λ = -2.8028957443981586 + 1.6019087098473328e-17im
# └   Δt = 0.035482401
# ┌ Info: VUMPS iteration:
# │   iter = 22
# │   ϵ = 0.0034975260246235406
# │   λ = -2.802898366975896 - 3.7838655819744105e-17im
# └   Δt = 0.035146134
# ┌ Info: VUMPS iteration:
# │   iter = 23
# │   ϵ = 0.003199938060136769
# │   λ = -2.802899369016105 - 3.122502256758253e-17im
# └   Δt = 0.041568718
# ┌ Info: VUMPS iteration:
# │   iter = 24
# │   ϵ = 0.003408884905670185
# │   λ = -2.802897875224716 + 1.0779680099937128e-16im
# └   Δt = 0.041633049
# ┌ Info: VUMPS iteration:
# │   iter = 25
# │   ϵ = 0.0030652826853538426
# │   λ = -2.8029016775826063 - 1.1893697832165984e-16im
# └   Δt = 0.04161402
# ┌ Info: VUMPS iteration:
# │   iter = 26
# │   ϵ = 0.003279386204953243
# │   λ = -2.8029012307499652 + 6.570265165262157e-17im
# └   Δt = 0.041401252
# ┌ Info: VUMPS iteration:
# │   iter = 27
# │   ϵ = 0.0031731375704952052
# │   λ = -2.8029018370600243 - 6.570265165262157e-17im
# └   Δt = 0.041702521
# ┌ Info: VUMPS iteration:
# │   iter = 28
# │   ϵ = 0.002844914961496257
# │   λ = -2.802904736858629 + 4.166046847775551e-17im
# └   Δt = 0.041525215
# ┌ Info: VUMPS iteration:
# │   iter = 29
# │   ϵ = 0.0028892568983572924
# │   λ = -2.8029017579099182 - 2.959871930885427e-17im
# └   Δt = 0.041517135
# ┌ Info: VUMPS iteration:
# │   iter = 30
# │   ϵ = 0.0029662746848739758
# │   λ = -2.802902071793418 - 1.2452061950996018e-16im
# └   Δt = 0.041699475
# ┌ Info: VUMPS iteration:
# │   iter = 31
# │   ϵ = 0.002906207378835041
# │   λ = -2.8029046030739577 - 1.1649752343356745e-16im
# └   Δt = 0.041620975
# ┌ Info: VUMPS iteration:
# │   iter = 32
# │   ϵ = 0.0027321670290531485
# │   λ = -2.8029044164906463 - 8.836247705756861e-18im
# └   Δt = 0.041475897
# ┌ Info: VUMPS iteration:
# │   iter = 33
# │   ϵ = 0.0028464763530508335
# │   λ = -2.802902682593094 - 1.973247953923618e-17im
# └   Δt = 0.041766339
# ┌ Info: VUMPS iteration:
# │   iter = 34
# │   ϵ = 0.002789688970024755
# │   λ = -2.8029054215776945 - 7.047314121155779e-18im
# └   Δt = 0.041577964
# ┌ Info: VUMPS iteration:
# │   iter = 35
# │   ϵ = 0.002502013812862114
# │   λ = -2.8029075384066786 + 1.3471211993132393e-17im
# └   Δt = 0.041569504
# ┌ Info: VUMPS iteration:
# │   iter = 36
# │   ϵ = 0.0024950990839908865
# │   λ = -2.8029070588877723 + 7.031051088568496e-17im
# └   Δt = 0.04171333
# ┌ Info: VUMPS iteration:
# │   iter = 37
# │   ϵ = 0.0026997703759315678
# │   λ = -2.8029051507716343 - 3.117081245895825e-17im
# └   Δt = 0.041677658
# ┌ Info: VUMPS iteration:
# │   iter = 38
# │   ϵ = 0.0026025199035379174
# │   λ = -2.8029056020628733 + 7.676151381197371e-17im
# └   Δt = 0.041504345
# ┌ Info: VUMPS iteration:
# │   iter = 39
# │   ϵ = 0.0025282750148642535
# │   λ = -2.802907649626494 + 8.218252467440124e-17im
# └   Δt = 0.041710767
# ┌ Info: VUMPS iteration:
# │   iter = 40
# │   ϵ = 0.0022575051763065457
# │   λ = -2.802909505184317 - 5.711204350156845e-17im
# └   Δt = 0.041828714
# ┌ Info: VUMPS iteration:
# │   iter = 41
# │   ϵ = 0.00231768213346977
# │   λ = -2.8029081007666377 + 1.457167719820518e-16im
# └   Δt = 0.041684854
# ┌ Info: VUMPS iteration:
# │   iter = 42
# │   ϵ = 0.00241837176052023
# │   λ = -2.8029072476882124 - 1.9456007985252377e-16im
# └   Δt = 0.041870969
# ┌ Info: VUMPS iteration:
# │   iter = 43
# │   ϵ = 0.0023729859147327017
# │   λ = -2.8029088204598835 - 7.979727989493313e-17im
# └   Δt = 0.041586949
# ┌ Info: VUMPS iteration:
# │   iter = 44
# │   ϵ = 0.0021707320947442483
# │   λ = -2.802910195520587 - 7.83336069620777e-17im
# └   Δt = 0.04156182
# ┌ Info: VUMPS iteration:
# │   iter = 45
# │   ϵ = 0.0021599614657874244
# │   λ = -2.802909969777877 + 1.5287250632045613e-16im
# └   Δt = 0.041978937
# ┌ Info: VUMPS iteration:
# │   iter = 46
# │   ϵ = 0.002211041083463572
# │   λ = -2.8029096756354246 + 5.421010862427522e-19im
# └   Δt = 0.041732594
# ┌ Info: VUMPS iteration:
# │   iter = 47
# │   ϵ = 0.002230208731102804
# │   λ = -2.802909072991465 + 3.233632979438017e-17im
# └   Δt = 0.041912804
# ┌ Info: VUMPS iteration:
# │   iter = 48
# │   ϵ = 0.002058287428961782
# │   λ = -2.8029107589297446 + 7.870630145886959e-18im
# └   Δt = 0.041879917
# ┌ Info: VUMPS iteration:
# │   iter = 49
# │   ϵ = 0.001982312556389185
# │   λ = -2.802911594930193 + 1.0142711323601894e-16im
# └   Δt = 0.041856044
# ┌ Info: VUMPS iteration:
# │   iter = 50
# │   ϵ = 0.0019909978077178444
# │   λ = -2.802911009318377 - 7.903833837419327e-17im
# └   Δt = 0.041875308
# ┌ Info: VUMPS iteration:
# │   iter = 51
# │   ϵ = 0.002016018381486444
# │   λ = -2.8029111060457597 + 3.2526065174565133e-18im
# └   Δt = 0.042262902
# ┌ Info: VUMPS iteration:
# │   iter = 52
# │   ϵ = 0.002053112728969757
# │   λ = -2.8029109991837196 - 3.69712940817557e-17im
# └   Δt = 0.042032281
# ┌ Info: VUMPS iteration:
# │   iter = 53
# │   ϵ = 0.0018756903343084613
# │   λ = -2.8029119071943054 - 1.4707202469765868e-16im
# └   Δt = 0.042010327
# ┌ Info: VUMPS iteration:
# │   iter = 54
# │   ϵ = 0.0018313069756149029
# │   λ = -2.8029122456812368 - 1.6317242695906842e-17im
# └   Δt = 0.041863684
# ┌ Info: VUMPS iteration:
# │   iter = 55
# │   ϵ = 0.0018032809635609652
# │   λ = -2.80291246370802 + 3.946495907847236e-17im
# └   Δt = 0.041802061
# ┌ Info: VUMPS iteration:
# │   iter = 56
# │   ϵ = 0.0018678501143115272
# │   λ = -2.8029117633051763 - 5.307169634316544e-17im
# └   Δt = 0.042026973
# ┌ Info: VUMPS iteration:
# │   iter = 57
# │   ϵ = 0.0017886859153278334
# │   λ = -2.8029125844886833 + 1.3812735677465326e-16im
# └   Δt = 0.042251466
# ┌ Info: VUMPS iteration:
# │   iter = 58
# │   ϵ = 0.0017194082890425158
# │   λ = -2.802913034559697 - 1.0711917464156784e-16im
# └   Δt = 0.042151205
# ┌ Info: VUMPS iteration:
# │   iter = 59
# │   ϵ = 0.0017002827139349123
# │   λ = -2.8029129352629996 - 2.5804011705155006e-17im
# └   Δt = 0.041946116
# ┌ Info: VUMPS iteration:
# │   iter = 60
# │   ϵ = 0.001670856257681009
# │   λ = -2.802913210008135 + 7.443047914112988e-17im
# └   Δt = 0.042074486
# ┌ Info: VUMPS iteration:
# │   iter = 61
# │   ϵ = 0.0016392202789173242
# │   λ = -2.802913442127647 - 6.207057437479513e-17im
# └   Δt = 0.04191972
# ┌ Info: VUMPS iteration:
# │   iter = 62
# │   ϵ = 0.0016404328717073463
# │   λ = -2.802913178017042 + 6.765421556309548e-17im
# └   Δt = 0.042387703
# ┌ Info: VUMPS iteration:
# │   iter = 63
# │   ϵ = 0.0015821196639733957
# │   λ = -2.802913753608808 + 1.1752751549742868e-16im
# └   Δt = 0.042419076
# ┌ Info: VUMPS iteration:
# │   iter = 64
# │   ϵ = 0.0015541268380591256
# │   λ = -2.802913856787155 + 3.491130995403324e-17im
# └   Δt = 0.041990567
# ┌ Info: VUMPS iteration:
# │   iter = 65
# │   ϵ = 0.0015759140845328851
# │   λ = -2.802913651884994 - 1.5954034968124198e-16im
# └   Δt = 0.04196993
# ┌ Info: VUMPS iteration:
# │   iter = 66
# │   ϵ = 0.0015039367871102767
# │   λ = -2.802914074024151 + 1.360673726469308e-16im
# └   Δt = 0.042047576
# ┌ Info: VUMPS iteration:
# │   iter = 67
# │   ϵ = 0.0014654570581922979
# │   λ = -2.80291432837015 - 4.336808689942018e-18im
# └   Δt = 0.041968623
# ┌ Info: VUMPS iteration:
# │   iter = 68
# │   ϵ = 0.0014610475803892857
# │   λ = -2.802914111473519 - 3.7947076036992655e-18im
# └   Δt = 0.042141139
# ┌ Info: VUMPS iteration:
# │   iter = 69
# │   ϵ = 0.0014209598391504085
# │   λ = -2.802914573211697 + 3.7513395167998453e-17im
# └   Δt = 0.042067393
# ┌ Info: VUMPS iteration:
# │   iter = 70
# │   ϵ = 0.0013860571215407239
# │   λ = -2.8029146773981513 - 9.90960785651751e-17im
# └   Δt = 0.042084127
# ┌ Info: VUMPS iteration:
# │   iter = 71
# │   ϵ = 0.0014227525996446005
# │   λ = -2.8029145073220594 + 3.778444571111983e-17im
# └   Δt = 0.041961138
# ┌ Info: VUMPS iteration:
# │   iter = 72
# │   ϵ = 0.0013379594225801036
# │   λ = -2.802915023166979 - 2.0057740190981832e-18im
# └   Δt = 0.04199792
# ┌ Info: VUMPS iteration:
# │   iter = 73
# │   ϵ = 0.0013197138335356291
# │   λ = -2.8029151070969913 - 1.1351596745923231e-16im
# └   Δt = 0.041916907
# ┌ Info: VUMPS iteration:
# │   iter = 74
# │   ϵ = 0.0013216455936649492
# │   λ = -2.8029149197937864 - 4.9981720151581754e-17im
# └   Δt = 0.042029715
# ┌ Info: VUMPS iteration:
# │   iter = 75
# │   ϵ = 0.0012692611052886483
# │   λ = -2.802915371739648 + 1.0191500421363742e-17im
# └   Δt = 0.04212606
# ┌ Info: VUMPS iteration:
# │   iter = 76
# │   ϵ = 0.0012409352603899193
# │   λ = -2.802915372726608 + 5.171644362755856e-17im
# └   Δt = 0.042109781
# ┌ Info: VUMPS iteration:
# │   iter = 77
# │   ϵ = 0.0012789220640574157
# │   λ = -2.802915194004548 - 1.496198998029996e-17im
# └   Δt = 0.04198832
# ┌ Info: VUMPS iteration:
# │   iter = 78
# │   ϵ = 0.001191922530883419
# │   λ = -2.8029156179055787 + 1.2072591190626092e-16im
# └   Δt = 0.042179386
# ┌ Info: VUMPS iteration:
# │   iter = 79
# │   ϵ = 0.0011868723971123932
# │   λ = -2.8029156445468235 + 8.922983879555701e-17im
# └   Δt = 0.042131236
# ┌ Info: VUMPS iteration:
# │   iter = 80
# │   ϵ = 0.0011892543339410285
# │   λ = -2.802915524379952 - 9.107298248878237e-17im
# └   Δt = 0.04204358
# ┌ Info: VUMPS iteration:
# │   iter = 81
# │   ϵ = 0.0011348274391157762
# │   λ = -2.802915878412387 + 2.2985086056692694e-17im
# └   Δt = 0.042358205
# ┌ Info: VUMPS iteration:
# │   iter = 82
# │   ϵ = 0.001110579708422554
# │   λ = -2.8029158701021633 - 6.505213034913027e-17im
# └   Δt = 0.042256966
# ┌ Info: VUMPS iteration:
# │   iter = 83
# │   ϵ = 0.001143902067308401
# │   λ = -2.8029157582966078 + 7.43762690325056e-17im
# └   Δt = 0.042195375
# ┌ Info: VUMPS iteration:
# │   iter = 84
# │   ϵ = 0.0010588542181405927
# │   λ = -2.802916084621798 + 8.055622141567298e-17im
# └   Δt = 0.042237254
# ┌ Info: VUMPS iteration:
# │   iter = 85
# │   ϵ = 0.0010652894663981337
# │   λ = -2.802916080322083 + 1.5829351718288365e-17im
# └   Δt = 0.042194209
# ┌ Info: VUMPS iteration:
# │   iter = 86
# │   ϵ = 0.0010640496189184263
# │   λ = -2.802916013091231 + 8.977193988179977e-17im
# └   Δt = 0.042040961
# ┌ Info: VUMPS iteration:
# │   iter = 87
# │   ϵ = 0.0010144154350798338
# │   λ = -2.8029162736118547 + 6.375108774214766e-17im
# └   Δt = 0.042315379
# ┌ Info: VUMPS iteration:
# │   iter = 88
# │   ϵ = 0.0009946391462252841
# │   λ = -2.8029162601763717 + 9.215718466126788e-18im
# └   Δt = 0.042148047
# ┌ Info: VUMPS iteration:
# │   iter = 89
# │   ϵ = 0.0010191783450378658
# │   λ = -2.8029162077715997 + 2.699663409488906e-17im
# └   Δt = 0.042133497
# ┌ Info: VUMPS iteration:
# │   iter = 90
# │   ϵ = 0.0009507486490234166
# │   λ = -2.8029164365594723 + 2.2768245622195593e-17im
# └   Δt = 0.042358901
# ┌ Info: VUMPS iteration:
# │   iter = 91
# │   ϵ = 0.0009550784061992643
# │   λ = -2.802916422623266 + 1.745565497701662e-17im
# └   Δt = 0.042233559
# ┌ Info: VUMPS iteration:
# │   iter = 92
# │   ϵ = 0.0009456583231032229
# │   λ = -2.802916399166153 - 3.361026734705064e-17im
# └   Δt = 0.042133359
# ┌ Info: VUMPS iteration:
# │   iter = 93
# │   ϵ = 0.0009092384661114217
# │   λ = -2.8029165714406634 + 5.97395397039513e-17im
# └   Δt = 0.042493796
# ┌ Info: VUMPS iteration:
# │   iter = 94
# │   ϵ = 0.0008936838186121135
# │   λ = -2.802916559423012 - 2.894819800536297e-17im
# └   Δt = 0.042476918
# ┌ Info: VUMPS iteration:
# │   iter = 95
# │   ϵ = 0.0009052895921668135
# │   λ = -2.80291655349386 + 8.868773770931426e-17im
# └   Δt = 0.042177444
# ┌ Info: VUMPS iteration:
# │   iter = 96
# │   ϵ = 0.0008638662097777859
# │   λ = -2.802916692449599 + 2.3418766925686896e-17im
# └   Δt = 0.042483609
# ┌ Info: VUMPS iteration:
# │   iter = 97
# │   ϵ = 0.000857975528520996
# │   λ = -2.802916685043784 + 6.288372600415926e-17im
# └   Δt = 0.042314256
# ┌ Info: VUMPS iteration:
# │   iter = 98
# │   ϵ = 0.0008375507199386385
# │   λ = -2.802916696367644 + 1.74122868901172e-16im
# └   Δt = 0.042139222
# ┌ Info: VUMPS iteration:
# │   iter = 99
# │   ϵ = 0.0008197186567300474
# │   λ = -2.802916794895852 - 1.0408340855860843e-16im
# └   Δt = 0.042404645
# ┌ Info: VUMPS iteration:
# │   iter = 100
# │   ϵ = 0.000810654519486857
# │   λ = -2.802916789757578 - 1.0419182877585698e-16im
# └   Δt = 0.0422604
# ┌ Warning: VUMPS maximum iterations
# │   iter = 100
# │   ϵ = 0.000810654519486857
# │   λ = -2.802916789757578 - 1.0419182877585698e-16im
# └ @ MPSKit ~/.julia/packages/MPSKit/atykv/src/algorithms/groundstate/vumps.jl:94
# ┌ Info: VUMPS summary:
# │   ϵ = 0.000810654519486857
# │   λ = -2.802916789757578 - 1.0419182877585698e-16im
# └   Δt = 4.300684426

# %% [markdown]
# We get convergence, but it takes an enormous amount of iterations.
# The reason behind this becomes more obvious at higher bond dimensions:

# %%
groundstate, cache, delta = find_groundstate(
    state, H2, IDMRG2(; trscheme=truncdim(50), maxiter=20, tol_galerkin=1e-12)
)
entanglementplot(groundstate)
# Out:
# [ Info: idmrg iter 1 err 0.10016151620309047
# [ Info: idmrg iter 2 err 0.053313307637041056
# [ Info: idmrg iter 3 err 0.0309034916447538
# [ Info: idmrg iter 4 err 0.016789265279534185
# [ Info: idmrg iter 5 err 0.008810548994775718
# [ Info: idmrg iter 6 err 0.0045657150470577185
# [ Info: idmrg iter 7 err 0.002356549928393464
# [ Info: idmrg iter 8 err 0.001214858002867114
# [ Info: idmrg iter 9 err 0.0006260733799961826
# [ Info: idmrg iter 10 err 0.0003226141536234266
# [ Info: idmrg iter 11 err 0.00016623804194757367
# [ Info: idmrg iter 12 err 8.565930524398552e-5
# [ Info: idmrg iter 13 err 4.413854422641036e-5
# [ Info: idmrg iter 14 err 2.274371146392133e-5
# [ Info: idmrg iter 15 err 1.1719380430303388e-5
# [ Info: idmrg iter 16 err 6.038762735149412e-6
# [ Info: idmrg iter 17 err 3.1116540216832894e-6
# [ Info: idmrg iter 18 err 1.603373509325929e-6
# [ Info: idmrg iter 19 err 8.261865426094501e-7
# [ Info: idmrg iter 20 err 4.2571712755898286e-7

# %% [markdown]
# We see that some eigenvalues clearly belong to a group, and are almost degenerate.
# This implies 2 things:
# - there is superfluous information, if those eigenvalues are the same anyway
# - poor convergence if we cut off within such a subspace
#
# It are precisely those problems that we can solve by using symmetries.

# %% [markdown]
# ## Symmetries
#
# The XXZ Heisenberg hamiltonian is SU(2) symmetric and we can exploit this to greatly speed up the simulation.
#
# It is cumbersome to construct symmetric hamiltonians, but luckily su(2) symmetric XXZ is already implemented:

# %%
H2 = heisenberg_XXX(ComplexF64, SU2Irrep, InfiniteChain(2); spin=1//2);

# %% [markdown]
# Our initial state should also be SU(2) symmetric.
# It now becomes apparent why we have to use a two-site periodic state.
# The physical space carries a half-integer charge and the first tensor maps the first `virtual_space ⊗ the physical_space` to the second `virtual_space`.
# Half-integer virtual charges will therefore map only to integer charges, and vice versa.
# The staggering thus happens on the virtual level.
#
# An alternative constructor for the initial state is

# %%
P = Rep[SU₂](1//2 => 1)
V1 = Rep[SU₂](1//2 => 10, 3//2 => 5, 5//2 => 2)
V2 = Rep[SU₂](0 => 15, 1 => 10, 2 => 5)
state = InfiniteMPS([P, P], [V1, V2]);

# %% [markdown]
# Even though the bond dimension is higher than in the example without symmetry, convergence is reached much faster:

# %%
println(dim(V1))
println(dim(V2))
groundstate, cache, delta = find_groundstate(
    state, H2, VUMPS(; maxiter=400, tol_galerkin=1e-12)
);
# Out:
# 52
# 70
# ┌ Info: VUMPS iteration:
# │   iter = 1
# │   ϵ = 0.15515975106883387
# │   λ = -0.8648282882853972 - 2.47198095326695e-17im
# └   Δt = 0.127803373
# ┌ Info: VUMPS iteration:
# │   iter = 2
# │   ϵ = 0.014279295994038354
# │   λ = -0.8854674953701709 + 9.685991158442375e-17im
# └   Δt = 0.123146715
# ┌ Info: VUMPS iteration:
# │   iter = 3
# │   ϵ = 0.0034651125150416437
# │   λ = -0.8861024520691171 + 6.65158032819857e-17im
# └   Δt = 0.097748928
# ┌ Info: VUMPS iteration:
# │   iter = 4
# │   ϵ = 0.0015671214289526543
# │   λ = -0.8862256619446776 - 6.613633252161577e-18im
# └   Δt = 0.108409665
# ┌ Info: VUMPS iteration:
# │   iter = 5
# │   ϵ = 0.0009763243212370736
# │   λ = -0.8862631582836693 + 4.911435841359335e-17im
# └   Δt = 0.123441343
# ┌ Info: VUMPS iteration:
# │   iter = 6
# │   ϵ = 0.0007622244550841027
# │   λ = -0.8862769928572388 + 5.128276275856436e-17im
# └   Δt = 0.127916801
# ┌ Info: VUMPS iteration:
# │   iter = 7
# │   ϵ = 0.0006078307169809947
# │   λ = -0.8862827473303712 - 1.1167282376600696e-17im
# └   Δt = 0.131391688
# ┌ Info: VUMPS iteration:
# │   iter = 8
# │   ϵ = 0.00046043180082545486
# │   λ = -0.8862853749663254 + 3.962758940434519e-17im
# └   Δt = 0.13084839
# ┌ Info: VUMPS iteration:
# │   iter = 9
# │   ϵ = 0.0003473672935808287
# │   λ = -0.8862866400231817 + 8.131516293641283e-19im
# └   Δt = 0.131548274
# ┌ Info: VUMPS iteration:
# │   iter = 10
# │   ϵ = 0.00026715381490111746
# │   λ = -0.8862872647659263 + 6.928051882182373e-17im
# └   Δt = 0.132402085
# ┌ Info: VUMPS iteration:
# │   iter = 11
# │   ϵ = 0.00020457600195454787
# │   λ = -0.8862875780944328 + 9.215718466126788e-18im
# └   Δt = 0.133046793
# ┌ Info: VUMPS iteration:
# │   iter = 12
# │   ϵ = 0.00015478475501714233
# │   λ = -0.8862877363192827 + 1.3010426069826053e-17im
# └   Δt = 0.163281349
# ┌ Info: VUMPS iteration:
# │   iter = 13
# │   ϵ = 0.00011567212248406538
# │   λ = -0.886287816361825 - 4.33138767907959e-17im
# └   Δt = 0.146913408
# ┌ Info: VUMPS iteration:
# │   iter = 14
# │   ϵ = 8.553710193491657e-5
# │   λ = -0.8862878568356587 - 4.569912157026401e-17im
# └   Δt = 0.163756278
# ┌ Info: VUMPS iteration:
# │   iter = 15
# │   ϵ = 6.272095137559682e-5
# │   λ = -0.8862878772790936 - 7.901123331988114e-17im
# └   Δt = 0.146308206
# ┌ Info: VUMPS iteration:
# │   iter = 16
# │   ϵ = 4.56939707541886e-5
# │   λ = -0.8862878875945929 - 1.0787811616230769e-16im
# └   Δt = 0.164548657
# ┌ Info: VUMPS iteration:
# │   iter = 17
# │   ϵ = 3.312754667754959e-5
# │   λ = -0.8862878927962566 - 4.3530717225293e-17im
# └   Δt = 0.142299386
# ┌ Info: VUMPS iteration:
# │   iter = 18
# │   ϵ = 2.3930362001795124e-5
# │   λ = -0.8862878954185759 + 9.459663954936026e-18im
# └   Δt = 0.143786468
# ┌ Info: VUMPS iteration:
# │   iter = 19
# │   ϵ = 1.724030214232632e-5
# │   λ = -0.8862878967406831 - 4.4181238528784306e-18im
# └   Δt = 0.160121267
# ┌ Info: VUMPS iteration:
# │   iter = 20
# │   ϵ = 1.2395820425975919e-5
# │   λ = -0.886287897407481 - 3.8977068100853884e-17im
# └   Δt = 0.142271584
# ┌ Info: VUMPS iteration:
# │   iter = 21
# │   ϵ = 8.899303482505931e-6
# │   λ = -0.8862878977439429 + 1.2088854223213374e-17im
# └   Δt = 0.143734598
# ┌ Info: VUMPS iteration:
# │   iter = 22
# │   ϵ = 6.381783347434108e-6
# │   λ = -0.8862878979138137 + 5.908901840045999e-17im
# └   Δt = 0.160389109
# ┌ Info: VUMPS iteration:
# │   iter = 23
# │   ϵ = 4.57240084087474e-6
# │   λ = -0.8862878979996278 - 1.9488534050426942e-17im
# └   Δt = 0.143340753
# ┌ Info: VUMPS iteration:
# │   iter = 24
# │   ϵ = 3.273727375390844e-6
# │   λ = -0.8862878980430069 - 1.1714804473705875e-16im
# └   Δt = 0.145292266
# ┌ Info: VUMPS iteration:
# │   iter = 25
# │   ϵ = 2.3425795867261826e-6
# │   λ = -0.8862878980649433 - 5.3478272157847506e-17im
# └   Δt = 0.159989356
# ┌ Info: VUMPS iteration:
# │   iter = 26
# │   ϵ = 1.6754907441882738e-6
# │   λ = -0.8862878980760442 - 2.6481638062958446e-17im
# └   Δt = 0.14384261
# ┌ Info: VUMPS iteration:
# │   iter = 27
# │   ϵ = 1.1978901713579633e-6
# │   λ = -0.8862878980816639 + 1.4934884925987824e-17im
# └   Δt = 0.162002411
# ┌ Info: VUMPS iteration:
# │   iter = 28
# │   ϵ = 8.561365999547603e-7
# │   λ = -0.8862878980845095 - 4.87890977618477e-19im
# └   Δt = 0.143648417
# ┌ Info: VUMPS iteration:
# │   iter = 29
# │   ϵ = 6.117001578050445e-7
# │   λ = -0.8862878980859523 + 3.775734065680769e-17im
# └   Δt = 0.14533889
# ┌ Info: VUMPS iteration:
# │   iter = 30
# │   ϵ = 4.369366283285856e-7
# │   λ = -0.8862878980866833 - 6.0986372202309624e-18im
# └   Δt = 0.162184468
# ┌ Info: VUMPS iteration:
# │   iter = 31
# │   ϵ = 3.120287004974068e-7
# │   λ = -0.8862878980870534 - 6.25584653524136e-17im
# └   Δt = 0.147265674
# ┌ Info: VUMPS iteration:
# │   iter = 32
# │   ϵ = 2.2278030513305591e-7
# │   λ = -0.8862878980872416 + 8.922983879555701e-17im
# └   Δt = 0.16360601
# ┌ Info: VUMPS iteration:
# │   iter = 33
# │   ϵ = 1.590281053162187e-7
# │   λ = -0.886287898087337 - 2.5614276324970042e-17im
# └   Δt = 0.147083028
# ┌ Info: VUMPS iteration:
# │   iter = 34
# │   ϵ = 1.13499304906689e-7
# │   λ = -0.8862878980873838 - 3.1387652893455353e-17im
# └   Δt = 0.149624752
# ┌ Info: VUMPS iteration:
# │   iter = 35
# │   ϵ = 8.099176710405684e-8
# │   λ = -0.8862878980874087 - 1.1132045805994917e-16im
# └   Δt = 0.162607464
# ┌ Info: VUMPS iteration:
# │   iter = 36
# │   ϵ = 5.778608559176724e-8
# │   λ = -0.8862878980874217 - 6.76000054544712e-17im
# └   Δt = 0.148460457
# ┌ Info: VUMPS iteration:
# │   iter = 37
# │   ϵ = 4.1223568529553974e-8
# │   λ = -0.8862878980874269 + 5.277354074573193e-17im
# └   Δt = 0.1652063
# ┌ Info: VUMPS iteration:
# │   iter = 38
# │   ϵ = 2.940442742646017e-8
# │   λ = -0.8862878980874307 - 1.3525422101756668e-17im
# └   Δt = 0.149147
# ┌ Info: VUMPS iteration:
# │   iter = 39
# │   ϵ = 2.0971483505499358e-8
# │   λ = -0.8862878980874309 + 2.7592945289756088e-17im
# └   Δt = 0.165899496
# ┌ Info: VUMPS iteration:
# │   iter = 40
# │   ϵ = 1.4955429349847724e-8
# │   λ = -0.8862878980874325 + 6.92534137675116e-17im
# └   Δt = 0.144797785
# ┌ Info: VUMPS iteration:
# │   iter = 41
# │   ϵ = 1.0664139562193869e-8
# │   λ = -0.8862878980874317 + 4.1714678586379783e-17im
# └   Δt = 0.163424311
# ┌ Info: VUMPS iteration:
# │   iter = 42
# │   ϵ = 7.603493493432011e-9
# │   λ = -0.8862878980874338 + 3.615814245239157e-17im
# └   Δt = 0.144812885
# ┌ Info: VUMPS iteration:
# │   iter = 43
# │   ϵ = 5.420813413994481e-9
# │   λ = -0.8862878980874327 - 1.3308581667259567e-17im
# └   Δt = 0.147504758
# ┌ Info: VUMPS iteration:
# │   iter = 44
# │   ϵ = 3.864404483306222e-9
# │   λ = -0.8862878980874336 + 1.132178118617988e-16im
# └   Δt = 0.162711822
# ┌ Info: VUMPS iteration:
# │   iter = 45
# │   ϵ = 2.754669093100426e-9
# │   λ = -0.8862878980874345 - 1.6534083130403943e-17im
# └   Δt = 0.146743485
# ┌ Info: VUMPS iteration:
# │   iter = 46
# │   ϵ = 1.9634924678509606e-9
# │   λ = -0.8862878980874338 + 2.6481638062958446e-17im
# └   Δt = 0.163891188
# ┌ Info: VUMPS iteration:
# │   iter = 47
# │   ϵ = 1.399466381815794e-9
# │   λ = -0.8862878980874336 - 7.318364664277155e-17im
# └   Δt = 0.131744491
# ┌ Info: VUMPS iteration:
# │   iter = 48
# │   ϵ = 9.974097213111077e-10
# │   λ = -0.8862878980874327 + 2.439454888092385e-19im
# └   Δt = 0.132485538
# ┌ Info: VUMPS iteration:
# │   iter = 49
# │   ϵ = 7.10820422629527e-10
# │   λ = -0.8862878980874342 + 7.524363077049401e-17im
# └   Δt = 0.133034486
# ┌ Info: VUMPS iteration:
# │   iter = 50
# │   ϵ = 5.065565412973433e-10
# │   λ = -0.8862878980874349 + 9.806608650131388e-17im
# └   Δt = 0.132576989
# ┌ Info: VUMPS iteration:
# │   iter = 51
# │   ϵ = 3.6097508771785333e-10
# │   λ = -0.8862878980874326 - 5.898059818321144e-17im
# └   Δt = 0.132066461
# ┌ Info: VUMPS iteration:
# │   iter = 52
# │   ϵ = 2.5722640633796827e-10
# │   λ = -0.8862878980874342 + 9.053088140253962e-18im
# └   Δt = 0.133089851
# ┌ Info: VUMPS iteration:
# │   iter = 53
# │   ϵ = 1.8328574187453506e-10
# │   λ = -0.8862878980874355 - 2.0491421059976034e-17im
# └   Δt = 0.148312872
# ┌ Info: VUMPS iteration:
# │   iter = 54
# │   ϵ = 1.3059565209121395e-10
# │   λ = -0.8862878980874334 - 5.889928302027503e-17im
# └   Δt = 0.132386047
# ┌ Info: VUMPS iteration:
# │   iter = 55
# │   ϵ = 9.305411147134367e-11
# │   λ = -0.8862878980874365 + 5.082197683525802e-17im
# └   Δt = 0.132335331
# ┌ Info: VUMPS iteration:
# │   iter = 56
# │   ϵ = 6.63027114992597e-11
# │   λ = -0.8862878980874342 + 1.0842021724855044e-18im
# └   Δt = 0.132542012
# ┌ Info: VUMPS iteration:
# │   iter = 57
# │   ϵ = 4.723619954231992e-11
# │   λ = -0.8862878980874326 - 9.52742659071637e-17im
# └   Δt = 0.132055581
# ┌ Info: VUMPS iteration:
# │   iter = 58
# │   ϵ = 3.36578269862377e-11
# │   λ = -0.8862878980874328 - 1.130009714273017e-16im
# └   Δt = 0.129902918
# ┌ Info: VUMPS iteration:
# │   iter = 59
# │   ϵ = 2.3975950964971392e-11
# │   λ = -0.8862878980874326 - 2.902951316829938e-17im
# └   Δt = 0.129592087
# ┌ Info: VUMPS iteration:
# │   iter = 60
# │   ϵ = 1.708352804252732e-11
# │   λ = -0.8862878980874345 - 4.149783815188268e-17im
# └   Δt = 0.130130419
# ┌ Info: VUMPS iteration:
# │   iter = 61
# │   ϵ = 1.2171402574740187e-11
# │   λ = -0.8862878980874345 - 4.957514433689969e-17im
# └   Δt = 0.121191463
# ┌ Info: VUMPS iteration:
# │   iter = 62
# │   ϵ = 8.664929649648852e-12
# │   λ = -0.8862878980874341 - 3.550762114890027e-18im
# └   Δt = 0.113041175
# ┌ Info: VUMPS iteration:
# │   iter = 63
# │   ϵ = 6.175652416435609e-12
# │   λ = -0.8862878980874329 + 3.892285799222961e-17im
# └   Δt = 0.114515486
# ┌ Info: VUMPS iteration:
# │   iter = 64
# │   ϵ = 4.4014738007597525e-12
# │   λ = -0.886287898087436 - 8.158621347953421e-17im
# └   Δt = 0.097652257
# ┌ Info: VUMPS iteration:
# │   iter = 65
# │   ϵ = 3.1310819775433348e-12
# │   λ = -0.8862878980874342 - 1.2766480581016815e-17im
# └   Δt = 0.112835078
# ┌ Info: VUMPS iteration:
# │   iter = 66
# │   ϵ = 2.229470013730169e-12
# │   λ = -0.8862878980874328 - 7.215365457891032e-17im
# └   Δt = 0.114714467
# ┌ Info: VUMPS iteration:
# │   iter = 67
# │   ϵ = 1.5908436326161845e-12
# │   λ = -0.8862878980874335 + 1.2847795743953228e-16im
# └   Δt = 0.114995141
# ┌ Info: VUMPS iteration:
# │   iter = 68
# │   ϵ = 1.1340549207357947e-12
# │   λ = -0.8862878980874342 + 1.280713816248502e-16im
# └   Δt = 0.096215977
# ┌ Info: VUMPS iteration:
# │   iter = 69
# │   ϵ = 8.082147970738424e-13
# │   λ = -0.8862878980874338 - 2.0383000842727483e-17im
# └   Δt = 0.112658014
# ┌ Info: VUMPS summary:
# │   ϵ = 8.082147970738424e-13
# │   λ = -0.8862878980874338 - 2.0383000842727483e-17im
# └   Δt = 10.879383578

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
